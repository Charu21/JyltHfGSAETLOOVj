# %%
# import libraries  
import numpy as np
import pandas as pd
import nltk
import re, random, os
import string, pprint
import matplotlib.pyplot as plt
import seaborn as sns

# spacy for basic preprocessing, optional, can use nltk as well (lemmatisation etc.)
import spacy

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Read and inspect the data

# %%
data = pd.read_csv("potential-talents.csv")
data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %%
data.fit.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
data['fit'].unique()
# Out:
# array([nan])

# %% [markdown]
# We see that the fit column has all values as Nan, so we can safely drop it.

# %%
data.drop('fit', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          104 non-null    int64
#  1   job_title   104 non-null    object
#  2   location    104 non-null    object
#  3   connection  104 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.4+ KB

# %% [markdown]
# ## 2. Data Cleaning and Preprocessing

# %%
# Checking for null values
data.isnull().sum()
# Out:
# id            0
# job_title     0
# location      0
# connection    0
# dtype: int64

# %%
# Finding unique values in each column
for col in data.columns:
    print(f'No. of unique values in {col} column = {data[col].nunique()}')
# Out:
# No. of unique values in id column = 104
# No. of unique values in job_title column = 52
# No. of unique values in location column = 41
# No. of unique values in connection column = 33

# %% [markdown]
# Here we see that id column values are almost double the job title column values. So there is a **possibility for duplicate entries** which can be deleted.

# %%
# Check for duplicate entries without id column
temp = data.drop(['id'], axis=1)
temp.head()
# Out:
#                                            job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (...
# 1  Native English Teacher at EPIK (English Progra...
# 2              Aspiring Human Resources Professional
# 3             People Development Coordinator at Ryan
# 4    Advisory Board Member at Celal Bayar University
#
#                               location connection
# 0                       Houston, Texas         85
# 1                               Kanada      500+
# 2  Raleigh-Durham, North Carolina Area         44
# 3                        Denton, Texas      500+
# 4                       İzmir, Türkiye      500+

# %%
temp.shape
# Out:
# (104, 3)

# %%
# Now finding duplicates and deleting them
temp.duplicated().sum()
# Out:
# 51

# %% [markdown]
# As we see there are 51 columns which are duplicate of each other, we can delete these.

# %%
new_df = temp.drop_duplicates()
new_df.shape
# Out:
# (53, 3)

# %%
df = pd.concat([data['id'], new_df], axis=1).dropna()
df = df.reset_index(drop = True)

# %%
df.shape
# Out:
# (53, 4)

# %%
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection
# 0                       Houston, Texas         85
# 1                               Kanada      500+
# 2  Raleigh-Durham, North Carolina Area         44
# 3                        Denton, Texas      500+
# 4                       İzmir, Türkiye      500+

# %% [markdown]
# #### a) Now taking the main query column that is JOB_TITLE and preprocessing it.

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Aspiring Human Resources Professional                                                                                    2
# 2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional                 1
# Lead Official at Western Illinois University                                                                             1
# Senior Human Resources Business Partner at Heil Environmental                                                            1
# Aspiring Human Resources Professional | An energetic and Team-Focused Leader                                             1
# HR Manager at Endemol Shine North America                                                                                1
# Human Resources professional for the world leader in GIS software                                                        1
# RRP Brand Portfolio Executive at JTI (Japan Tobacco International)                                                       1
# Information Systems Specialist and Programmer with a love for data and organization.                                     1
# Bachelor of Science in Biology from Victoria University of Wellington                                                    1
# Human Resources Management Major                                                                                         1
# Director Human Resources  at EY                                                                                          1
# Undergraduate Research Assistant at Styczynski Lab                                                                       1
# Seeking employment opportunities within Customer Service or Patient Care                                                 1
# Liberal Arts Major. Aspiring Human Resources Analyst.                                                                    1
# Admissions Representative at Community medical center long beach                                                         1
# Seeking Human  Resources Opportunities. Open to travel and relocation.                                                   1
# Student at Westfield State University                                                                                    1
# Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint               1
# Student                                                                                                                  1
# Seeking Human Resources Position                                                                                         1
# Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis    1
# Human Resources Generalist at Loparex                                                                                    1
# Business Intelligence and Analytics at Travelers                                                                         1
# Always set them up for Success                                                                                           1
# Junior MES Engineer| Information Systems                                                                                 1
# Human Resources Generalist at Schwan's                                                                                   1
# Native English Teacher at EPIK (English Program in Korea)                                                                1
# Seeking Human Resources Opportunities                                                                                    1
# People Development Coordinator at Ryan                                                                                   1
# Advisory Board Member at Celal Bayar University                                                                          1
# Aspiring Human Resources Specialist                                                                                      1
# Student at Humber College and Aspiring Human Resources Generalist                                                        1
# HR Senior Specialist                                                                                                     1
# Seeking Human Resources HRIS and Generalist Positions                                                                    1
# Student at Chapman University                                                                                            1
# SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR              1
# Human Resources Coordinator at InterContinental Buckhead Atlanta                                                         1
# Aspiring Human Resources Management student seeking an internship                                                        1
# Experienced Retail Manager and aspiring Human Resources Professional                                                     1
# Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation                  1
# Human Resources, Staffing and Recruiting Professional                                                                    1
# Human Resources Specialist at Luxottica                                                                                  1
# Director of Human Resources North America, Groupe Beneteau                                                               1
# Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.                           1
# Human Resources Generalist at ScottMadden, Inc.                                                                          1
# Business Management Major and Aspiring Human Resources Manager                                                           1
# Aspiring Human Resources Manager, seeking internship in Human Resources.                                                 1
# Human Resources Professional                                                                                             1
# Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621                     1
# Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment    1
# Director Of Administration at Excellence Logging                                                                         1
# Name: count, dtype: int64

# %% [markdown]
# From the above we can see a number of things for **text pre-processing**:
# 1. Expanding abbreviations and new lines and numbers
# 2. Convert to lower case and remove unwanted characters like punctuation symbols from the text. - what we see is characters like | or ! or \n or opening closing brackets which need to be handled.
# 3. Then we will remove **stop words** and go for stemming or/and lemmatization.

# %%
# Expanding abbreviations and removing \n and numbers
df.replace({'job_title' : { 'HR' : 'human resources', 'GIS': 'geographic information system',
                           'EY': 'Ernst & Young Global Limited', 'MES': 'Manufacturing execution systems',
                           'CHRO' : 'chief human resources officer', 'SVP' : 'senior vice president',
                           'CSR' : 'corporate social responsibility', 'GPHR' : 'global professional in human resources',
                           'SPHR' : 'strategic and policy-making certification', 'HRIS' : 'human resources management system',  
                           'C.T.' : '', 'EPIK': 'english program in korea',
                           '\n': '', '\w*\d\w*': ''
    }}, regex=True, inplace=True)

# %%
# Removing punctuation and changing to lowercase
punct_chars = set(string.punctuation)
df['job_title'] = df['job_title'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))
df['job_title'] = df['job_title'].str.lower()

df['job_title'].value_counts()
# Out:
# job_title
# aspiring human resources professional                                                                                                                                                     2
#   bauer college of business graduate magna cum laude and aspiring human resources professional                                                                                            1
# lead official at western illinois university                                                                                                                                              1
# senior human resources business partner at heil environmental                                                                                                                             1
# aspiring human resources professional  an energetic and teamfocused leader                                                                                                                1
# human resources manager at endemol shine north america                                                                                                                                    1
# human resources professional for the world leader in geographic information system software                                                                                               1
# rrp brand portfolio executive at jti japan tobacco international                                                                                                                          1
# information systems specialist and programmer with a love for data and organization                                                                                                       1
# bachelor of science in biology from victoria university of wellington                                                                                                                     1
# human resources management major                                                                                                                                                          1
# director human resources  at ernst  young global limited                                                                                                                                  1
# undergraduate research assistant at styczynski lab                                                                                                                                        1
# seeking employment opportunities within customer service or patient care                                                                                                                  1
# liberal arts major aspiring human resources analyst                                                                                                                                       1
# admissions representative at community medical center long beach                                                                                                                          1
# seeking human  resources opportunities open to travel and relocation                                                                                                                      1
# student at westfield state university                                                                                                                                                     1
# student at indiana university kokomo  business management  retail manager at delphi hardware and paint                                                                                    1
# student                                                                                                                                                                                   1
# seeking human resources position                                                                                                                                                          1
# aspiring human resources manager  graduating may   seeking an entrylevel human resources position in st louis                                                                             1
# human resources generalist at loparex                                                                                                                                                     1
# business intelligence and analytics at travelers                                                                                                                                          1
# always set them up for success                                                                                                                                                            1
# junior manufacturing execution systems engineer information systems                                                                                                                       1
# human resources generalist at schwans                                                                                                                                                     1
# native english teacher at english program in korea english program in korea                                                                                                               1
# seeking human resources opportunities                                                                                                                                                     1
# people development coordinator at ryan                                                                                                                                                    1
# advisory board member at celal bayar university                                                                                                                                           1
# aspiring human resources specialist                                                                                                                                                       1
# student at humber college and aspiring human resources generalist                                                                                                                         1
# human resources senior specialist                                                                                                                                                         1
# seeking human resources human resourcesis and generalist positions                                                                                                                        1
# student at chapman university                                                                                                                                                             1
# senior vice president chuman resourceso marketing  communications corporate social responsibility officer  engie  houston  the woodlands  energy  gphuman resources  sphuman resources    1
# human resources coordinator at intercontinental buckhead atlanta                                                                                                                          1
# aspiring human resources management student seeking an internship                                                                                                                         1
# experienced retail manager and aspiring human resources professional                                                                                                                      1
# human resourcesconflict managementpolicies  procedurestalent managementbenefits  compensation                                                                                             1
# human resources staffing and recruiting professional                                                                                                                                      1
# human resources specialist at luxottica                                                                                                                                                   1
# director of human resources north america groupe beneteau                                                                                                                                 1
# retired army national guard recruiter office manager  seeking a position in human resources                                                                                               1
# human resources generalist at scottmadden inc                                                                                                                                             1
# business management major and aspiring human resources manager                                                                                                                            1
# aspiring human resources manager seeking internship in human resources                                                                                                                    1
# human resources professional                                                                                                                                                              1
# nortia staffing is seeking human resources payroll  administrative professionals                                                                                                          1
# aspiring human resources professional  passionate about helping to create an inclusive and engaging work environment                                                                      1
# director of administration at excellence logging                                                                                                                                          1
# Name: count, dtype: int64

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
stop_nltk = set(stopwords.words('english'))
lemmatiser = WordNetLemmatizer()

# %%
def preprocess_text(dataframe, col):
    for i in range(len(dataframe)):
        tokens = word_tokenize(dataframe.iloc[i][col])
        tokens_no_stopwords = [word for word in tokens if word not in stop_nltk]
        final_sentence = []
        for word in tokens_no_stopwords:
            final_sentence.append(lemmatiser.lemmatize(word))
        dataframe[col][i]=' '.join([str(elem) for elem in final_sentence])

# %%
nltk.download('punkt')
nltk.download('wordnet')
preprocess_text(df, 'job_title')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CHARU\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\CHARU\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df.head()
# Out:
#    id                                          job_title  \
# 0   1  bauer college business graduate magna cum laud...
# 1   2  native english teacher english program korea e...
# 2   3               aspiring human resource professional
# 3   4                people development coordinator ryan
# 4   5       advisory board member celal bayar university
#
#                               location connection
# 0                       Houston, Texas         85
# 1                               Kanada      500+
# 2  Raleigh-Durham, North Carolina Area         44
# 3                        Denton, Texas      500+
# 4                       İzmir, Türkiye      500+

# %% [markdown]
# ### b) Now similar preprocessing for LOCATION

# %%
df['location'].value_counts()
# Out:
# location
# Houston, Texas Area                    4
# Raleigh-Durham, North Carolina Area    3
# Greater New York City Area             3
# Austin, Texas Area                     2
# Amerika Birleşik Devletleri            2
# Kanada                                 2
# Greater Philadelphia Area              2
# Greater Atlanta Area                   2
# Torrance, California                   1
# Highland, California                   1
# Gaithersburg, Maryland                 1
# Baltimore, Maryland                    1
# Milpitas, California                   1
# Greater Chicago Area                   1
# Houston, Texas                         1
# Long Beach, California                 1
# Chattanooga, Tennessee Area            1
# Bridgewater, Massachusetts             1
# Lafayette, Indiana                     1
# Kokomo, Indiana Area                   1
# Las Vegas, Nevada Area                 1
# Cape Girardeau, Missouri               1
# Greater Los Angeles Area               1
# Los Angeles, California                1
# Dallas/Fort Worth Area                 1
# Myrtle Beach, South Carolina Area      1
# Baton Rouge, Louisiana Area            1
# New York, New York                     1
# San Jose, California                   1
# Greater Boston Area                    1
# Monroe, Louisiana Area                 1
# Virginia Beach, Virginia               1
# Greater Grand Rapids, Michigan Area    1
# Jackson, Mississippi Area              1
# Chicago, Illinois                      1
# Atlanta, Georgia                       1
# Lake Forest, California                1
# San Francisco Bay Area                 1
# İzmir, Türkiye                         1
# Denton, Texas                          1
# Katy, Texas                            1
# Name: count, dtype: int64

# %%
# Removing punctuations and correcting misspelt word(s)
punct_chars = punct_chars.difference(set([',']))
df['location'] = df['location'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))
df['location'] = df['location'].str.lower()
df.replace({'location' : {'amerika birleşik devletleri' : 'united states of america',
                           'kanada' : 'canada', 'türkiye' : 'turkey',
    }}, regex=True, inplace=True)
df.head()
# Out:
#    id                                          job_title  \
# 0   1  bauer college business graduate magna cum laud...
# 1   2  native english teacher english program korea e...
# 2   3               aspiring human resource professional
# 3   4                people development coordinator ryan
# 4   5       advisory board member celal bayar university
#
#                              location connection
# 0                      houston, texas         85
# 1                              canada      500+
# 2  raleighdurham, north carolina area         44
# 3                       denton, texas      500+
# 4                      i̇zmir, turkey      500+

# %%
preprocess_text(df, 'location')
df.head()
# Out:
#    id                                          job_title  \
# 0   1  bauer college business graduate magna cum laud...
# 1   2  native english teacher english program korea e...
# 2   3               aspiring human resource professional
# 3   4                people development coordinator ryan
# 4   5       advisory board member celal bayar university
#
#                               location connection
# 0                      houston , texas         85
# 1                               canada      500+
# 2  raleighdurham , north carolina area         44
# 3                       denton , texas      500+
# 4                      i̇zmir , turkey      500+

# %% [markdown]
# ### b) Preprocessing for CONNECTION

# %%
#We need to normalize the connections to be between 0-1. We will count 500+ as 500

# Function to normalize scores to between 0-1
def normalize_score(score):
    if score == '500+ ':
        score = 500
    return float(score)/500

df['connection'] = df['connection'].apply(normalize_score)
df.head()
# Out:
#    id                                          job_title  \
# 0   1  bauer college business graduate magna cum laud...
# 1   2  native english teacher english program korea e...
# 2   3               aspiring human resource professional
# 3   4                people development coordinator ryan
# 4   5       advisory board member celal bayar university
#
#                               location  connection
# 0                      houston , texas       0.170
# 1                               canada       1.000
# 2  raleighdurham , north carolina area       0.088
# 3                       denton , texas       1.000
# 4                      i̇zmir , turkey       1.000

# %% [markdown]
# ## 3. Word Embeddings

# %% [markdown]
# We will now convert the words or tokens into vectors , ie, continuous-valued vectors in a high-dimensional space to capture the semantic relationships between words. The methods we will use are :
# 1) **TF-IDF** is a classic metric that calculates the importance of a term in a document relative to a collection of documents.
# 2) **Word2Vec** It is a shallow neural network-based model that learns word embeddings by predicting words in their context (CBOW) or predicting context words given a target word (Skip-gram).
# 3) **Glove** It is a count-based model that learns word embeddings based on the co-occurrence statistics of words in a large corpus.
# 4) **FastText** It represents words as the sum of their constituent subword embeddings (character n-grams) for capturing more meaning.
# 5) **BERT** It is a contextual embedding model that pre-trains on massive text corpora and captures word meanings in context.

# %% [markdown]
# ### Chosen Performance metric : Cosine Similarity

# %% [markdown]
# We need to find how fit the candidate is for the role. As stated in the problem statement, it should be a **number**, like probability between 0-1. So for this case **cosine similarity** seems the closest needed to fit our criterion. As it is apt for text-oriented searches through which we can gauge the **similarity between two vectors**, such as query and document vectors.
# As our use case is one of ranking and performing **document search** , cosine similarity is the apt metric.
# <p><i>NOTE:</i> The <u>final ranking fitness</u> score will also take into account the starring feedback loop action.</p>

# %% [markdown]
# ### 1) Beginning with TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorizer instantiation
tfidf = TfidfVectorizer()

# Create tfidf matrix
tf_matrix = tfidf.fit_transform(df['job_title'])

# Shape of matrix
print(tf_matrix.shape)
# Out:
# (53, 181)

# %%
data = pd.DataFrame(tf_matrix.toarray(), columns=tfidf.get_feature_names_out())
data
# Out:
#     administration  administrative  admission  advisory   always   america  \
# 0         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 1         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 2         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 3         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 4         0.000000        0.000000   0.000000  0.426332  0.00000  0.000000
# 5         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 6         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 7         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 8         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 9         0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 10        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 11        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 12        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 13        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 14        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 15        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 16        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 17        0.000000        0.000000   0.000000  0.000000  0.00000  0.423798
# 18        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 19        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 20        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 21        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 22        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 23        0.000000        0.457845   0.000000  0.000000  0.00000  0.000000
# 24        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 25        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 26        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 27        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 28        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 29        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 30        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 31        0.000000        0.000000   0.000000  0.000000  0.00000  0.435626
# 32        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 33        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 34        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 35        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 36        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 37        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 38        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 39        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 40        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 41        0.000000        0.000000   0.377964  0.000000  0.00000  0.000000
# 42        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 43        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 44        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 45        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 46        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 47        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 48        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 49        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 50        0.000000        0.000000   0.000000  0.000000  0.00000  0.000000
# 51        0.000000        0.000000   0.000000  0.000000  0.57735  0.000000
# 52        0.519642        0.000000   0.000000  0.000000  0.00000  0.000000
#
#      analyst  analytics      army       art  ...      vice  victoria  \
# 0   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 3   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 4   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 5   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 6   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 7   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 8   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 9   0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 10  0.000000   0.000000  0.000000  0.000000  ...  0.241481  0.000000
# 11  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 12  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 13  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 14  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 15  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 16  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 17  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 18  0.000000   0.000000  0.361216  0.000000  ...  0.000000  0.000000
# 19  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 20  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 21  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 22  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 23  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 24  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 25  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 26  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 27  0.486486   0.000000  0.000000  0.486486  ...  0.000000  0.000000
# 28  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 29  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 30  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 31  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 32  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 33  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 34  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 35  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.426332
# 36  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 37  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 38  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 39  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 40  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 41  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 42  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 43  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 44  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 45  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 46  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 47  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 48  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 49  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 50  0.000000   0.530452  0.000000  0.000000  ...  0.000000  0.000000
# 51  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 52  0.000000   0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
#     wellington  western  westfield    within  woodland      work    world  \
# 0     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 1     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 2     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 3     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 4     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 5     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 6     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 7     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 8     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 9     0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 10    0.000000  0.00000   0.000000  0.000000  0.241481  0.000000  0.00000
# 11    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 12    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 13    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 14    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 15    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 16    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 17    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 18    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 19    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 20    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 21    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 22    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 23    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 24    0.000000  0.00000   0.000000  0.000000  0.000000  0.356104  0.00000
# 25    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 26    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 27    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 28    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 29    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 30    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 31    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 32    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.41475
# 33    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 34    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 35    0.426332  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 36    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 37    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 38    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 39    0.000000  0.47131   0.000000  0.000000  0.000000  0.000000  0.00000
# 40    0.000000  0.00000   0.000000  0.376165  0.000000  0.000000  0.00000
# 41    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 42    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 43    0.000000  0.00000   0.577004  0.000000  0.000000  0.000000  0.00000
# 44    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 45    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 46    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 47    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 48    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 49    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 50    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 51    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
# 52    0.000000  0.00000   0.000000  0.000000  0.000000  0.000000  0.00000
#
#        young
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000
# 20  0.000000
# 21  0.000000
# 22  0.000000
# 23  0.000000
# 24  0.000000
# 25  0.000000
# 26  0.000000
# 27  0.000000
# 28  0.000000
# 29  0.000000
# 30  0.000000
# 31  0.000000
# 32  0.000000
# 33  0.000000
# 34  0.000000
# 35  0.000000
# 36  0.000000
# 37  0.450557
# 38  0.000000
# 39  0.000000
# 40  0.000000
# 41  0.000000
# 42  0.000000
# 43  0.000000
# 44  0.000000
# 45  0.000000
# 46  0.000000
# 47  0.000000
# 48  0.000000
# 49  0.000000
# 50  0.000000
# 51  0.000000
# 52  0.000000
#
# [53 rows x 181 columns]

# %%
# Function for cleaning and preprocessing of query terms
def preprocessing_keywords(keywords):
    keywords = re.sub('[^a-zA-Z]', ' ', keywords) # remove punctuations and numbers
    keywords = str(keywords).lower()              # lowercase
    tokens = word_tokenize(keywords)          
    keywords_no_stopwords = [word for word in tokens if word not in stop_nltk]
    keywords = [lemmatiser.lemmatize(word=word) for word in keywords_no_stopwords]
    keywords = ' '.join(keywords)
    return keywords

# %% [markdown]
# #### Let us start with our search term keywords as "Aspiring human resources"

# %%
keyword = 'Aspiring human resources'

# Preprocess these words
keyword_cleaned = preprocessing_keywords(keyword)
print(f'{keyword_cleaned}')
# Out:
# aspiring human resource

# %%
tfidf_keyword = tfidf.transform([keyword_cleaned])
print(tfidf_keyword.shape)
# Out:
# (1, 181)

# %%
# Now computing cosine similarity
from sklearn.metrics.pairwise import cosine_similarity

# %%
cos_sim = cosine_similarity(tf_matrix, tfidf_keyword)

cos_data = { 'tfidf_fit' : cos_sim.ravel()}
cos_df = pd.DataFrame(cos_data)
cos_df.head()
# Out:
#    tfidf_fit
# 0   0.268142
# 1   0.000000
# 2   0.767650
# 3   0.000000
# 4   0.000000

# %%
## Creating a final dataset with the performance metrics appended
final_df = pd.concat([df, cos_df], axis=1)
final_df.head()
# Out:
#    id                                          job_title  \
# 0   1  bauer college business graduate magna cum laud...
# 1   2  native english teacher english program korea e...
# 2   3               aspiring human resource professional
# 3   4                people development coordinator ryan
# 4   5       advisory board member celal bayar university
#
#                               location  connection  tfidf_fit
# 0                      houston , texas       0.170   0.268142
# 1                               canada       1.000   0.000000
# 2  raleighdurham , north carolina area       0.088   0.767650
# 3                       denton , texas       1.000   0.000000
# 4                      i̇zmir , turkey       1.000   0.000000

# %%
# Let us sort the dataframe to have the job_titles which have closest fit to our keywords search query
sorted_df = final_df.sort_values(['tfidf_fit'], ascending=False)
sorted_df.head(6)
# Out:
#     id                                          job_title  \
# 45  97               aspiring human resource professional
# 2    3               aspiring human resource professional
# 5    6                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking intern...
# 12  27  aspiring human resource management student see...
# 20  72  business management major aspiring human resou...
#
#                                location  connection  tfidf_fit
# 45                kokomo , indiana area       0.142   0.767650
# 2   raleighdurham , north carolina area       0.088   0.767650
# 5            greater new york city area       0.002   0.676406
# 21                 houston , texas area       0.014   0.612429
# 12                 houston , texas area       1.000   0.429728
# 20              monroe , louisiana area       0.010   0.427448

# %%
sorted_df['job_title'].head(6).tolist()
# Out:
# ['aspiring human resource professional',
#  'aspiring human resource professional',
#  'aspiring human resource specialist',
#  'aspiring human resource manager seeking internship human resource',
#  'aspiring human resource management student seeking internship',
#  'business management major aspiring human resource manager']

# %% [markdown]
# Here we find the top 5 <b>job_titles</b> similar to <b><i>"Aspiring human resources"</b></i> are:
# * aspiring human resource professional with similarity 76.76%
# * aspiring human resource specialist with similarity 67.64%
# * aspiring human resource manager seeking internship human resource with similarity 61.2%
# * aspiring human resource management student seeking internship with similarity 42.97%
# * business management major aspiring human resource manager with similarity 42.74%

# %%
pd.set_option('display.max_colwidth', None)

# %%
## Function to do above all steps in one go
def top_talent(job_title):
    keyword_cleaned = preprocessing_keywords(job_title)
    tfidf_keyword = tfidf.transform([keyword_cleaned])
    cos_sim = cosine_similarity(tf_matrix, tfidf_keyword)
    cos_data = { 'tfidf_fit' : cos_sim.ravel()}
    cos_df = pd.DataFrame(cos_data)
    temp_df = pd.concat([df, cos_df], axis=1)
    return sorted_df

# %%
top_talent('Aspiring human resources').sort_values(['tfidf_fit'], ascending=False).head(5)
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit
# 45                kokomo , indiana area       0.142   0.767650
# 2   raleighdurham , north carolina area       0.088   0.767650
# 5            greater new york city area       0.002   0.676406
# 21                 houston , texas area       0.014   0.612429
# 12                 houston , texas area       1.000   0.429728

# %% [markdown]
# #### Let us also check for keywords: "seeking human resources"

# %%
final_df_kw2 = top_talent('seeking human resources')
final_df_kw2.sort_values(['tfidf_fit'], ascending=False).head(5)
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit
# 45                kokomo , indiana area       0.142   0.767650
# 2   raleighdurham , north carolina area       0.088   0.767650
# 5            greater new york city area       0.002   0.676406
# 21                 houston , texas area       0.014   0.612429
# 12                 houston , texas area       1.000   0.429728

# %% [markdown]
# ### 2) Word2Vec

# %%
import gensim
import warnings
warnings.filterwarnings('ignore')
import multiprocessing
from gensim.models.phrases import Phrases, Phraser

# %%
df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection
# 0                      houston , texas       0.170
# 1                               canada       1.000
# 2  raleighdurham , north carolina area       0.088
# 3                       denton , texas       1.000
# 4                      i̇zmir , turkey       1.000

# %%
corpus = [words.split() for words in df['job_title']]
corpus
# Out:
# [['bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resource',
#   'professional'],
#  ['native',
#   'english',
#   'teacher',
#   'english',
#   'program',
#   'korea',
#   'english',
#   'program',
#   'korea'],
#  ['aspiring', 'human', 'resource', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'celal', 'bayar', 'university'],
#  ['aspiring', 'human', 'resource', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resource',
#   'generalist'],
#  ['human', 'resource', 'senior', 'specialist'],
#  ['seeking',
#   'human',
#   'resource',
#   'human',
#   'resourcesis',
#   'generalist',
#   'position'],
#  ['student', 'chapman', 'university'],
#  ['senior',
#   'vice',
#   'president',
#   'chuman',
#   'resourceso',
#   'marketing',
#   'communication',
#   'corporate',
#   'social',
#   'responsibility',
#   'officer',
#   'engie',
#   'houston',
#   'woodland',
#   'energy',
#   'gphuman',
#   'resource',
#   'sphuman',
#   'resource'],
#  ['human',
#   'resource',
#   'coordinator',
#   'intercontinental',
#   'buckhead',
#   'atlanta'],
#  ['aspiring',
#   'human',
#   'resource',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resource', 'opportunity'],
#  ['experienced',
#   'retail',
#   'manager',
#   'aspiring',
#   'human',
#   'resource',
#   'professional'],
#  ['human', 'resource', 'staffing', 'recruiting', 'professional'],
#  ['human', 'resource', 'specialist', 'luxottica'],
#  ['director', 'human', 'resource', 'north', 'america', 'groupe', 'beneteau'],
#  ['retired',
#   'army',
#   'national',
#   'guard',
#   'recruiter',
#   'office',
#   'manager',
#   'seeking',
#   'position',
#   'human',
#   'resource'],
#  ['human', 'resource', 'generalist', 'scottmadden', 'inc'],
#  ['business',
#   'management',
#   'major',
#   'aspiring',
#   'human',
#   'resource',
#   'manager'],
#  ['aspiring',
#   'human',
#   'resource',
#   'manager',
#   'seeking',
#   'internship',
#   'human',
#   'resource'],
#  ['human', 'resource', 'professional'],
#  ['nortia',
#   'staffing',
#   'seeking',
#   'human',
#   'resource',
#   'payroll',
#   'administrative',
#   'professional'],
#  ['aspiring',
#   'human',
#   'resource',
#   'professional',
#   'passionate',
#   'helping',
#   'create',
#   'inclusive',
#   'engaging',
#   'work',
#   'environment'],
#  ['human',
#   'resourcesconflict',
#   'managementpolicies',
#   'procedurestalent',
#   'managementbenefits',
#   'compensation'],
#  ['human', 'resource', 'generalist', 'schwans'],
#  ['liberal', 'art', 'major', 'aspiring', 'human', 'resource', 'analyst'],
#  ['junior',
#   'manufacturing',
#   'execution',
#   'system',
#   'engineer',
#   'information',
#   'system'],
#  ['senior',
#   'human',
#   'resource',
#   'business',
#   'partner',
#   'heil',
#   'environmental'],
#  ['aspiring',
#   'human',
#   'resource',
#   'professional',
#   'energetic',
#   'teamfocused',
#   'leader'],
#  ['human', 'resource', 'manager', 'endemol', 'shine', 'north', 'america'],
#  ['human',
#   'resource',
#   'professional',
#   'world',
#   'leader',
#   'geographic',
#   'information',
#   'system',
#   'software'],
#  ['rrp',
#   'brand',
#   'portfolio',
#   'executive',
#   'jti',
#   'japan',
#   'tobacco',
#   'international'],
#  ['information',
#   'system',
#   'specialist',
#   'programmer',
#   'love',
#   'data',
#   'organization'],
#  ['bachelor', 'science', 'biology', 'victoria', 'university', 'wellington'],
#  ['human', 'resource', 'management', 'major'],
#  ['director', 'human', 'resource', 'ernst', 'young', 'global', 'limited'],
#  ['undergraduate', 'research', 'assistant', 'styczynski', 'lab'],
#  ['lead', 'official', 'western', 'illinois', 'university'],
#  ['seeking',
#   'employment',
#   'opportunity',
#   'within',
#   'customer',
#   'service',
#   'patient',
#   'care'],
#  ['admission',
#   'representative',
#   'community',
#   'medical',
#   'center',
#   'long',
#   'beach'],
#  ['seeking',
#   'human',
#   'resource',
#   'opportunity',
#   'open',
#   'travel',
#   'relocation'],
#  ['student', 'westfield', 'state', 'university'],
#  ['student',
#   'indiana',
#   'university',
#   'kokomo',
#   'business',
#   'management',
#   'retail',
#   'manager',
#   'delphi',
#   'hardware',
#   'paint'],
#  ['aspiring', 'human', 'resource', 'professional'],
#  ['student'],
#  ['seeking', 'human', 'resource', 'position'],
#  ['aspiring',
#   'human',
#   'resource',
#   'manager',
#   'graduating',
#   'may',
#   'seeking',
#   'entrylevel',
#   'human',
#   'resource',
#   'position',
#   'st',
#   'louis'],
#  ['human', 'resource', 'generalist', 'loparex'],
#  ['business', 'intelligence', 'analytics', 'traveler'],
#  ['always', 'set', 'success'],
#  ['director', 'administration', 'excellence', 'logging']]

# %%
w2vmodel = gensim.models.Word2Vec(corpus, min_count=1, workers = multiprocessing.cpu_count(), 
                                  vector_size=100, epochs=30)

# %%
w2vmodel

# %%
w2vmodel.wv["aspiring"]
# Out:
# array([-2.21384433e-03,  5.07073337e-03, -6.95561524e-03,  2.94341851e-04,
#         7.75390398e-03,  3.52842221e-03, -2.67321314e-03,  6.81405794e-03,
#        -1.15574645e-02,  6.01049978e-03, -4.79733804e-03, -6.11406891e-03,
#         9.48811881e-03,  2.63728155e-03,  7.81554077e-03, -5.36438031e-03,
#         5.88819245e-03,  6.00915169e-03, -9.92803834e-03, -9.92780644e-03,
#        -5.54706110e-03, -3.40491580e-03, -3.87486839e-03, -1.02112200e-02,
#         7.74142100e-03, -3.69489472e-03,  7.36223813e-03,  3.65609396e-03,
#        -8.41954723e-03,  4.35816916e-03,  6.97632600e-03, -7.10925553e-03,
#        -6.79161120e-03, -3.19447601e-03, -9.22233239e-03,  3.00661661e-03,
#         1.31044909e-03,  2.91950838e-03,  1.83283677e-03, -3.52096767e-03,
#        -5.64593729e-03, -1.58958440e-03, -3.74302920e-03,  6.38566352e-03,
#         6.02450361e-03,  4.15194593e-03,  5.47890784e-04, -2.77629285e-03,
#        -2.31837621e-03,  4.50074673e-04,  3.15941032e-03, -4.22517490e-03,
#        -5.17041981e-03, -8.34030658e-03, -8.14182311e-03, -4.62935306e-03,
#        -5.71662618e-04, -3.22680362e-03, -8.35041329e-03, -6.92284142e-04,
#         3.02832690e-03, -3.32399621e-03,  8.55373498e-03,  6.83629332e-05,
#        -9.36924946e-03,  1.08199921e-02,  9.53360088e-03,  9.96126980e-03,
#        -8.15221760e-03,  1.07998457e-02,  2.51401262e-03,  5.87534625e-03,
#         5.44044934e-03,  1.20726076e-03, -1.79459841e-03,  9.43349674e-03,
#         1.03787789e-02,  2.88391649e-03, -4.87095024e-03,  1.46603491e-03,
#         6.21033367e-04, -7.13882176e-03, -9.67781898e-03,  4.55399090e-03,
#         7.65802455e-04, -6.00803923e-03, -3.39078135e-03, -5.26575604e-03,
#         1.14045534e-02,  1.16085261e-03, -1.93179992e-03,  8.17979965e-03,
#         9.44554619e-03, -1.96941174e-03,  1.27457138e-02,  7.97852222e-03,
#         7.77904317e-03, -1.06907892e-03,  8.34741350e-03, -6.35740813e-03],
#       dtype=float32)

# %%
def check_present_in_model(token, model):
    if model.wv.__contains__(token) == True:
        return model.wv[token]
    else:
        return np.zeros(100)

# %%
def calculate_vector(input, model):
    query_tokens = input.split()
    query_vector = check_present_in_model(query_tokens[0], model)
    
    for token in query_tokens[1:]:
        query_vector = query_vector + check_present_in_model(token, model)

    query_vector = query_vector / len(query_tokens)
    return query_vector

# %%
w2vmodel.wv['college']
# Out:
# array([-8.7073585e-03, -9.1235840e-04, -8.0804192e-03,  8.9676762e-03,
#         6.0702991e-03,  2.3903321e-03,  9.2701092e-03,  2.5726387e-03,
#        -1.2056711e-02,  9.0783825e-03, -4.8670354e-03,  5.8739623e-03,
#         5.7388837e-03,  5.9800721e-05, -7.3451903e-03, -7.8591792e-04,
#         6.8201590e-03, -1.0004920e-02,  2.5494376e-04, -1.1656916e-02,
#         9.7782193e-03, -1.6266612e-03,  9.2604579e-03, -6.9672181e-03,
#        -9.9078640e-03, -7.9289768e-03, -4.8611234e-03,  3.3800271e-03,
#        -1.5858081e-03,  9.4573433e-03,  3.9221593e-03,  4.0529040e-03,
#         3.5757334e-03,  7.8469068e-03, -3.0084215e-03,  1.1160766e-02,
#        -8.1678657e-03,  2.5565471e-03, -3.7057896e-04, -1.5962666e-03,
#         6.7856722e-03, -5.3728945e-03, -4.5289327e-03, -1.8327226e-04,
#         1.1380890e-03, -3.9495160e-03,  5.5922484e-03, -6.6196970e-03,
#         9.3545979e-03,  1.0165565e-03,  3.9174072e-03,  2.1714813e-03,
#         9.9074154e-04,  1.2273814e-03, -2.4351210e-03,  5.6173322e-03,
#         1.2396219e-03, -2.3736299e-03, -1.0024680e-02, -7.8311572e-03,
#        -8.0825540e-04, -5.4482743e-03, -1.0359769e-03, -5.4864739e-03,
#        -1.0298336e-02,  2.1452722e-03,  7.4468916e-03,  1.1941920e-03,
#        -8.3225397e-03,  6.8259989e-03, -1.4783164e-03, -4.9903863e-03,
#        -3.6848712e-04, -1.1687336e-03, -2.0803136e-03, -9.0845525e-03,
#         8.2098516e-03,  2.9654412e-03, -4.2548338e-03,  8.4462678e-03,
#         1.9976166e-04,  8.2317898e-03, -2.4862203e-03,  1.1179965e-02,
#        -3.9194844e-04, -6.2008165e-03, -3.8275414e-03,  1.1428908e-02,
#         2.9319630e-03,  1.8902036e-03,  1.0379096e-02, -4.3345452e-03,
#        -1.6273563e-03, -6.5453337e-03, -2.8454375e-03, -6.6467891e-03,
#         5.5245897e-03,  1.5308460e-03,  6.1324066e-03,  2.9892717e-03],
#       dtype=float32)

# %%
query_vector = calculate_vector(preprocessing_keywords('aspiring human resources'), w2vmodel)
job_title_scores = {}
for job_title in final_df['job_title']:
    job_title_vector = calculate_vector(job_title, w2vmodel)
    similarity_score = w2vmodel.wv.cosine_similarities(query_vector, [job_title_vector])[0]
    job_title_scores[job_title] = similarity_score

for title, score in job_title_scores.items():
    print(title, score)
# Out:
# bauer college business graduate magna cum laude aspiring human resource professional 0.8619738
# native english teacher english program korea english program korea 0.56780547
# aspiring human resource professional 0.95190215
# people development coordinator ryan 0.51234156
# advisory board member celal bayar university 0.61254036
# aspiring human resource specialist 0.94967794
# student humber college aspiring human resource generalist 0.89007705
# human resource senior specialist 0.8344201
# seeking human resource human resourcesis generalist position 0.8804667
# student chapman university 0.43617266
# senior vice president chuman resourceso marketing communication corporate social responsibility officer engie houston woodland energy gphuman resource sphuman resource 0.8021904
# human resource coordinator intercontinental buckhead atlanta 0.7947706
# aspiring human resource management student seeking internship 0.85901463
# seeking human resource opportunity 0.8841362
# experienced retail manager aspiring human resource professional 0.87301767
# human resource staffing recruiting professional 0.7883171
# human resource specialist luxottica 0.8266708
# director human resource north america groupe beneteau 0.7724776
# retired army national guard recruiter office manager seeking position human resource 0.82872695
# human resource generalist scottmadden inc 0.8334269
# business management major aspiring human resource manager 0.915736
# aspiring human resource manager seeking internship human resource 0.94520766
# human resource professional 0.87929374
# nortia staffing seeking human resource payroll administrative professional 0.8147034
# aspiring human resource professional passionate helping create inclusive engaging work environment 0.814263
# human resourcesconflict managementpolicies procedurestalent managementbenefits compensation 0.7060766
# human resource generalist schwans 0.81035495
# liberal art major aspiring human resource analyst 0.8902322
# junior manufacturing execution system engineer information system 0.62640005
# senior human resource business partner heil environmental 0.837309
# aspiring human resource professional energetic teamfocused leader 0.8958723
# human resource manager endemol shine north america 0.8142108
# human resource professional world leader geographic information system software 0.8113377
# rrp brand portfolio executive jti japan tobacco international 0.70752746
# information system specialist programmer love data organization 0.57133293
# bachelor science biology victoria university wellington 0.541275
# human resource management major 0.8610948
# director human resource ernst young global limited 0.8454459
# undergraduate research assistant styczynski lab 0.47879225
# lead official western illinois university 0.5849271
# seeking employment opportunity within customer service patient care 0.6226023
# admission representative community medical center long beach 0.6570669
# seeking human resource opportunity open travel relocation 0.7909001
# student westfield state university 0.5027117
# student indiana university kokomo business management retail manager delphi hardware paint 0.66964585
# student 0.22914416
# seeking human resource position 0.89477897
# aspiring human resource manager graduating may seeking entrylevel human resource position st louis 0.9117487
# human resource generalist loparex 0.8098227
# business intelligence analytics traveler 0.5524525
# always set success 0.34049797
# director administration excellence logging 0.3636127

# %%
## Assigning these values to our final_df

# %%
final_df['Word2Vec_Fit'] = final_df['job_title'].map(job_title_scores)
final_df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection  tfidf_fit  Word2Vec_Fit
# 0                      houston , texas       0.170   0.268142      0.861974
# 1                               canada       1.000   0.000000      0.567805
# 2  raleighdurham , north carolina area       0.088   0.767650      0.951902
# 3                       denton , texas       1.000   0.000000      0.512342
# 4                      i̇zmir , turkey       1.000   0.000000      0.612540

# %% [markdown]
# #### Let us also check for keywords: "seeking human resources"

# %%
query_vector = calculate_vector(preprocessing_keywords('seeking human resources'), w2vmodel)
job_title_scores = {}
for job_title in final_df['job_title']:
    job_title_vector = calculate_vector(job_title, w2vmodel)
    similarity_score = w2vmodel.wv.cosine_similarities(query_vector, [job_title_vector])[0]
    job_title_scores[job_title] = similarity_score

# %%
# Adding these to our second keywords table as well
final_df_kw2['Word2Vec_Fit'] = final_df_kw2['job_title'].map(job_title_scores)
final_df_kw2.head()
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit  Word2Vec_Fit
# 45                kokomo , indiana area       0.142   0.767650      0.859485
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 5            greater new york city area       0.002   0.676406      0.842872
# 21                 houston , texas area       0.014   0.612429      0.946601
# 12                 houston , texas area       1.000   0.429728      0.855958

# %% [markdown]
# #### Some <i><u>utility functions</i></u> which will be needed for multiple algorithms :

# %%
# Function to calculate cosine similarity for checking closeness of search query vector
def cosine_sim(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    
    if norm_vec1 == 0 or norm_vec2 == 0:
        return 0.0  # Handle the case of zero vectors
    
    similarity = dot_product / (norm_vec1 * norm_vec2)
    return similarity

# %%
# Function to calculate average of the word vectors
def average_word_vectors(words, model, size):
    word_vectors = [model[word] if word in model else np.zeros(size) for word in words]
    if word_vectors:
        return np.mean(word_vectors, axis=0)
    else:
        return np.zeros(size)

# %%
def calculate_similarity(model, query, size):
    if size == -1 :
        size = model.vector_size
    job_title_vectors = [average_word_vectors(job_title.split(), model, size) for job_title in final_df['job_title']]
    query_vector = np.mean([model[word] if word in model else np.zeros(size) for word in preprocessing_keywords(query).split()], axis=0)
    similarities = [cosine_sim(query_vector, title_vector) for title_vector in job_title_vectors]
    return similarities

# %% [markdown]
# ### 2.b) Using Google's pretrained Word2vec model

# %% [markdown]
# Apart from our own created Word2vec model with limited context, we will also be trying with a  <b><u>pretrained word2vec model</b></u> which will be trained on a massive corpus and may capture the semantic language patterns better. So trying with Google's pretrained Word2Vec model as well.

# %%
from gensim.models import KeyedVectors

# %%
google_word2vec = 'GoogleNews-vectors-negative300.bin.gz'

# %%
google_model = KeyedVectors.load_word2vec_format(google_word2vec, binary=True)

# %%
google_similarities = calculate_similarity(google_model, 'aspiring human resources',-1)
final_df['Google_Word2vec_fit'] = google_similarities
final_df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection  tfidf_fit  Word2Vec_Fit  \
# 0                      houston , texas       0.170   0.268142      0.861974
# 1                               canada       1.000   0.000000      0.567805
# 2  raleighdurham , north carolina area       0.088   0.767650      0.951902
# 3                       denton , texas       1.000   0.000000      0.512342
# 4                      i̇zmir , turkey       1.000   0.000000      0.612540
#
#    Google_Word2vec_fit
# 0             0.623142
# 1             0.219639
# 2             0.950395
# 3             0.253594
# 4             0.206563

# %%
# Also trying for our second set of keywords
google_similarities_2 = calculate_similarity(google_model, 'seeking human resources', -1)
final_df_kw2['Google_Word2vec_fit'] = google_similarities_2
final_df_kw2.head()
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 45                kokomo , indiana area       0.142   0.767650      0.859485
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 5            greater new york city area       0.002   0.676406      0.842872
# 21                 houston , texas area       0.014   0.612429      0.946601
# 12                 houston , texas area       1.000   0.429728      0.855958
#
#     Google_Word2vec_fit
# 45             0.422934
# 2              0.127382
# 5              0.723763
# 21             0.268558
# 12             0.237063

# %% [markdown]
# ### 3) Now applying Glove

# %%
glove_file = 'glove.6B.300d.word2vec.txt'

# %%
# Load the GloVe word vectors into Gensim format
glove_model = KeyedVectors.load_word2vec_format(glove_file, binary=False)

# %%
title_similarities = calculate_similarity(glove_model, 'aspiring human resources', -1)
final_df['Glove_fit'] = title_similarities
final_df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection  tfidf_fit  Word2Vec_Fit  \
# 0                      houston , texas       0.170   0.268142      0.861974
# 1                               canada       1.000   0.000000      0.567805
# 2  raleighdurham , north carolina area       0.088   0.767650      0.951902
# 3                       denton , texas       1.000   0.000000      0.512342
# 4                      i̇zmir , turkey       1.000   0.000000      0.612540
#
#    Google_Word2vec_fit  Glove_fit
# 0             0.623142   0.552778
# 1             0.219639   0.376623
# 2             0.950395   0.924892
# 3             0.253594   0.451536
# 4             0.206563   0.262758

# %%
final_df.sort_values('Glove_fit', ascending=False).head(5)
# Out:
#     id                                                          job_title  \
# 5    6                                 aspiring human resource specialist
# 2    3                               aspiring human resource professional
# 45  97                               aspiring human resource professional
# 21  73  aspiring human resource manager seeking internship human resource
# 22  74                                        human resource professional
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 5            greater new york city area       0.002   0.676406      0.949678
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 21                 houston , texas area       0.014   0.612429      0.945208
# 22                  greater boston area       0.032   0.402560      0.879294
#
#     Google_Word2vec_fit  Glove_fit
# 5              0.912262   0.934877
# 2              0.950395   0.924892
# 45             0.950395   0.924892
# 21             0.875945   0.908395
# 22             0.874494   0.871642

# %%
# Also trying for our second set of keywords
title_similarities = calculate_similarity(glove_model, 'seeking human resources', -1)
final_df_kw2['Glove_fit'] = title_similarities
final_df_kw2.head()
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 45                kokomo , indiana area       0.142   0.767650      0.859485
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 5            greater new york city area       0.002   0.676406      0.842872
# 21                 houston , texas area       0.014   0.612429      0.946601
# 12                 houston , texas area       1.000   0.429728      0.855958
#
#     Google_Word2vec_fit  Glove_fit
# 45             0.422934   0.459776
# 2              0.127382   0.403659
# 5              0.723763   0.792764
# 21             0.268558   0.513656
# 12             0.237063   0.305832

# %% [markdown]
# ### 4) Now applying FastText

# %%
import fasttext
import fasttext.util

# %%
fasttext.util.download_model('en', if_exists='ignore')  # English
# Out:
# 'cc.en.300.bin'

# %%
fasttext_model = fasttext.load_model('cc.en.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Get embeddings for the query
search_query = 'aspiring human resources'
query_vector = fasttext_model.get_sentence_vector(preprocessing_keywords(search_query))

# %%
title_similarities = calculate_similarity(fasttext_model, 'aspiring human resources', 300)
final_df['Fasttext_Fit'] = title_similarities
final_df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection  tfidf_fit  Word2Vec_Fit  \
# 0                      houston , texas       0.170   0.268142      0.861974
# 1                               canada       1.000   0.000000      0.567805
# 2  raleighdurham , north carolina area       0.088   0.767650      0.951902
# 3                       denton , texas       1.000   0.000000      0.512342
# 4                      i̇zmir , turkey       1.000   0.000000      0.612540
#
#    Google_Word2vec_fit  Glove_fit  Fasttext_Fit
# 0             0.623142   0.552778      0.458525
# 1             0.219639   0.376623      0.301101
# 2             0.950395   0.924892      0.984363
# 3             0.253594   0.451536      0.300589
# 4             0.206563   0.262758      0.236510

# %%
final_df.sort_values('Fasttext_Fit', ascending=False).head(5)
# Out:
#     id                                                          job_title  \
# 2    3                               aspiring human resource professional
# 45  97                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 22  74                                        human resource professional
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 22                  greater boston area       0.032   0.402560      0.879294
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit
# 2              0.950395   0.924892      0.984363
# 45             0.950395   0.924892      0.984363
# 5              0.912262   0.934877      0.969928
# 21             0.875945   0.908395      0.938275
# 22             0.874494   0.871642      0.931923

# %%
# Also trying for our second set of keywords
title_similarities = calculate_similarity(fasttext_model, 'seeking human resources', 300)
final_df_kw2['Fasttext_Fit'] = title_similarities
final_df_kw2.head()
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 45                kokomo , indiana area       0.142   0.767650      0.859485
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 5            greater new york city area       0.002   0.676406      0.842872
# 21                 houston , texas area       0.014   0.612429      0.946601
# 12                 houston , texas area       1.000   0.429728      0.855958
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit
# 45             0.422934   0.459776      0.388841
# 2              0.127382   0.403659      0.252584
# 5              0.723763   0.792764      0.877064
# 21             0.268558   0.513656      0.281134
# 12             0.237063   0.305832      0.235586

# %%
final_df_kw2.sort_values('Fasttext_Fit', ascending=False).head(5)
# Out:
#     id                                                  job_title  \
# 13  28                         seeking human resource opportunity
# 38  90            undergraduate research assistant styczynski lab
# 6    7  student humber college aspiring human resource generalist
# 16  68                        human resource specialist luxottica
# 15  67            human resource staffing recruiting professional
#
#                       location  connection  tfidf_fit  Word2Vec_Fit  \
# 13          chicago , illinois       0.780   0.271462      0.943784
# 38        greater atlanta area       0.310   0.000000      0.425043
# 6                       canada       0.122   0.391946      0.801875
# 16  greater new york city area       1.000   0.227186      0.808715
# 15  jackson , mississippi area       1.000   0.198735      0.795123
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit
# 13             0.904508   0.956014      0.977981
# 38             0.918737   0.938362      0.959728
# 6              0.870324   0.914206      0.947450
# 16             0.842598   0.908195      0.931645
# 15             0.799299   0.855232      0.911936

# %% [markdown]
# ### 5) Now applying BERT

# %%
from transformers import BertTokenizer, BertModel

# %%
model_name = "bert-base-uncased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# %%
import torch

# Encoding the job titles with BERT
embeddings = []
for job_title in final_df['job_title']:
    inputs = tokenizer(job_title, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        output = model(**inputs)
    embeddings.append(output.pooler_output.numpy())

# %%
query_1 = 'aspiring human resources'
query_2 = 'seeking human resources'

query1_inputs = tokenizer(query_1, return_tensors = 'pt', padding=True, truncation=True)
query2_inputs = tokenizer(query_2, return_tensors = 'pt', padding=True, truncation=True)

# %%
# Processing 
with torch.no_grad():
    query1_output = model(**query1_inputs)
    query2_output = model(**query2_inputs)
query1_embedding = query1_output.pooler_output.numpy()
query2_embedding = query2_output.pooler_output.numpy()

# %%
# Now calculating similarities for query 1
similarities = []
for embedding in embeddings:
    similarity = cosine_similarity(embedding, query1_embedding)
    similarities.append(similarity)
    
final_df['Bert_fit'] = np.vstack(similarities).ravel()
final_df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection  tfidf_fit  Word2Vec_Fit  \
# 0                      houston , texas       0.170   0.268142      0.861974
# 1                               canada       1.000   0.000000      0.567805
# 2  raleighdurham , north carolina area       0.088   0.767650      0.951902
# 3                       denton , texas       1.000   0.000000      0.512342
# 4                      i̇zmir , turkey       1.000   0.000000      0.612540
#
#    Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 0             0.623142   0.552778      0.458525  0.899871
# 1             0.219639   0.376623      0.301101  0.876270
# 2             0.950395   0.924892      0.984363  0.933594
# 3             0.253594   0.451536      0.300589  0.842620
# 4             0.206563   0.262758      0.236510  0.839048

# %%
# Now calculating similarities for query 2
similarities2 = []
for embedding in embeddings:
    similarity = cosine_similarity(embedding, query2_embedding)
    similarities2.append(similarity)
    
final_df_kw2['Bert_fit'] = np.vstack(similarities2).ravel()
final_df_kw2.head()
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 45                kokomo , indiana area       0.142   0.767650      0.859485
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 5            greater new york city area       0.002   0.676406      0.842872
# 21                 houston , texas area       0.014   0.612429      0.946601
# 12                 houston , texas area       1.000   0.429728      0.855958
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 45             0.422934   0.459776      0.388841  0.888918
# 2              0.127382   0.403659      0.252584  0.867738
# 5              0.723763   0.792764      0.877064  0.924877
# 21             0.268558   0.513656      0.281134  0.827690
# 12             0.237063   0.305832      0.235586  0.832970

# %% [markdown]
# ### Finalizing what will be our FIT function.

# %% [markdown]
# Let us look at our applied algorithms by **visual table inspection** which is showing best current fit for the keyword searches of
# * a) Aspiring human resources
# * b) seeking human resources

# %% [markdown]
# ### 1) For "Aspiring human resources"

# %%
# For Keyword set a)
final_df.head(5)
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                               job_title  \
# 0  bauer college business graduate magna cum laude aspiring human resource professional
# 1                    native english teacher english program korea english program korea
# 2                                                  aspiring human resource professional
# 3                                                   people development coordinator ryan
# 4                                          advisory board member celal bayar university
#
#                               location  connection  tfidf_fit  Word2Vec_Fit  \
# 0                      houston , texas       0.170   0.268142      0.861974
# 1                               canada       1.000   0.000000      0.567805
# 2  raleighdurham , north carolina area       0.088   0.767650      0.951902
# 3                       denton , texas       1.000   0.000000      0.512342
# 4                      i̇zmir , turkey       1.000   0.000000      0.612540
#
#    Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 0             0.623142   0.552778      0.458525  0.899871
# 1             0.219639   0.376623      0.301101  0.876270
# 2             0.950395   0.924892      0.984363  0.933594
# 3             0.253594   0.451536      0.300589  0.842620
# 4             0.206563   0.262758      0.236510  0.839048

# %% [markdown]
# We will get first 10 sorted outputs by each algorithm to see which works better. So,

# %% [markdown]
# #### a) For TFIDF

# %%
final_df.sort_values(['tfidf_fit'], ascending=False).head(10)
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
# 20  72          business management major aspiring human resource manager
# 14  66    experienced retail manager aspiring human resource professional
# 22  74                                        human resource professional
# 6    7          student humber college aspiring human resource generalist
# 30  82  aspiring human resource professional energetic teamfocused leader
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 12                 houston , texas area       1.000   0.429728      0.859015
# 20              monroe , louisiana area       0.010   0.427448      0.915736
# 14                  austin , texas area       0.114   0.406130      0.873018
# 22                  greater boston area       0.032   0.402560      0.879294
# 6                                canada       0.122   0.391946      0.890077
# 30                  austin , texas area       0.348   0.375301      0.895872
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 45             0.950395   0.924892      0.984363  0.933594
# 2              0.950395   0.924892      0.984363  0.933594
# 5              0.912262   0.934877      0.969928  0.964565
# 21             0.875945   0.908395      0.938275  0.922119
# 12             0.783973   0.815054      0.866789  0.936784
# 20             0.760062   0.756317      0.812208  0.931662
# 14             0.779507   0.768465      0.833309  0.844770
# 22             0.874494   0.871642      0.931923  0.958796
# 6              0.829068   0.738099      0.797077  0.900687
# 30             0.827266   0.824088      0.885884  0.888631

# %% [markdown]
# #### b) For Word2Vec

# %%
final_df.sort_values(['Word2Vec_Fit'], ascending=False).head(10)
# Out:
#      id  \
# 2     3
# 45   97
# 5     6
# 21   73
# 20   72
# 48  100
# 30   82
# 47   99
# 27   79
# 6     7
#
#                                                                                              job_title  \
# 2                                                                 aspiring human resource professional
# 45                                                                aspiring human resource professional
# 5                                                                   aspiring human resource specialist
# 21                                   aspiring human resource manager seeking internship human resource
# 20                                           business management major aspiring human resource manager
# 48  aspiring human resource manager graduating may seeking entrylevel human resource position st louis
# 30                                   aspiring human resource professional energetic teamfocused leader
# 47                                                                     seeking human resource position
# 27                                                   liberal art major aspiring human resource analyst
# 6                                            student humber college aspiring human resource generalist
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 20              monroe , louisiana area       0.010   0.427448      0.915736
# 48            cape girardeau , missouri       0.206   0.373131      0.911749
# 30                  austin , texas area       0.348   0.375301      0.895872
# 47                la vega , nevada area       0.096   0.280808      0.894779
# 27         baton rouge , louisiana area       0.014   0.351478      0.890232
# 6                                canada       0.122   0.391946      0.890077
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 2              0.950395   0.924892      0.984363  0.933594
# 45             0.950395   0.924892      0.984363  0.933594
# 5              0.912262   0.934877      0.969928  0.964565
# 21             0.875945   0.908395      0.938275  0.922119
# 20             0.760062   0.756317      0.812208  0.931662
# 48             0.791290   0.774596      0.584913  0.882259
# 30             0.827266   0.824088      0.885884  0.888631
# 47             0.728513   0.785119      0.850613  0.959093
# 27             0.731783   0.760117      0.723149  0.899233
# 6              0.829068   0.738099      0.797077  0.900687

# %% [markdown]
# #### c) For Google Word2Vec

# %%
final_df.sort_values(['Google_Word2vec_fit'], ascending=False).head(10)
# Out:
#      id  \
# 2     3
# 45   97
# 5     6
# 21   73
# 22   74
# 6     7
# 30   82
# 48  100
# 12   27
# 26   78
#
#                                                                                              job_title  \
# 2                                                                 aspiring human resource professional
# 45                                                                aspiring human resource professional
# 5                                                                   aspiring human resource specialist
# 21                                   aspiring human resource manager seeking internship human resource
# 22                                                                         human resource professional
# 6                                            student humber college aspiring human resource generalist
# 30                                   aspiring human resource professional energetic teamfocused leader
# 48  aspiring human resource manager graduating may seeking entrylevel human resource position st louis
# 12                                       aspiring human resource management student seeking internship
# 26                                                                   human resource generalist schwans
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 22                  greater boston area       0.032   0.402560      0.879294
# 6                                canada       0.122   0.391946      0.890077
# 30                  austin , texas area       0.348   0.375301      0.895872
# 48            cape girardeau , missouri       0.206   0.373131      0.911749
# 12                 houston , texas area       1.000   0.429728      0.859015
# 26                 united state america       1.000   0.231303      0.810355
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 2              0.950395   0.924892      0.984363  0.933594
# 45             0.950395   0.924892      0.984363  0.933594
# 5              0.912262   0.934877      0.969928  0.964565
# 21             0.875945   0.908395      0.938275  0.922119
# 22             0.874494   0.871642      0.931923  0.958796
# 6              0.829068   0.738099      0.797077  0.900687
# 30             0.827266   0.824088      0.885884  0.888631
# 48             0.791290   0.774596      0.584913  0.882259
# 12             0.783973   0.815054      0.866789  0.936784
# 26             0.780322   0.797933      0.889861  0.976990

# %% [markdown]
# #### d) For Glove

# %%
final_df.sort_values(['Glove_fit'], ascending=False).head(10)
# Out:
#     id                                                          job_title  \
# 5    6                                 aspiring human resource specialist
# 2    3                               aspiring human resource professional
# 45  97                               aspiring human resource professional
# 21  73  aspiring human resource manager seeking internship human resource
# 22  74                                        human resource professional
# 13  28                                 seeking human resource opportunity
# 30  82  aspiring human resource professional energetic teamfocused leader
# 12  27      aspiring human resource management student seeking internship
# 8   10       seeking human resource human resourcesis generalist position
# 26  78                                  human resource generalist schwans
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 5            greater new york city area       0.002   0.676406      0.949678
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 21                 houston , texas area       0.014   0.612429      0.945208
# 22                  greater boston area       0.032   0.402560      0.879294
# 13                   chicago , illinois       0.780   0.271462      0.884136
# 30                  austin , texas area       0.348   0.375301      0.895872
# 12                 houston , texas area       1.000   0.429728      0.859015
# 8             greater philadelphia area       1.000   0.262936      0.880467
# 26                 united state america       1.000   0.231303      0.810355
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 5              0.912262   0.934877      0.969928  0.964565
# 2              0.950395   0.924892      0.984363  0.933594
# 45             0.950395   0.924892      0.984363  0.933594
# 21             0.875945   0.908395      0.938275  0.922119
# 22             0.874494   0.871642      0.931923  0.958796
# 13             0.756767   0.837561      0.877444  0.975341
# 30             0.827266   0.824088      0.885884  0.888631
# 12             0.783973   0.815054      0.866789  0.936784
# 8              0.760450   0.805695      0.884100  0.845393
# 26             0.780322   0.797933      0.889861  0.976990

# %% [markdown]
# #### e) For Fasttext

# %%
final_df.sort_values(['Fasttext_Fit'], ascending=False).head(10)
# Out:
#      id                                                          job_title  \
# 2     3                               aspiring human resource professional
# 45   97                               aspiring human resource professional
# 5     6                                 aspiring human resource specialist
# 21   73  aspiring human resource manager seeking internship human resource
# 22   74                                        human resource professional
# 16   68                                human resource specialist luxottica
# 26   78                                  human resource generalist schwans
# 49  101                                  human resource generalist loparex
# 30   82  aspiring human resource professional energetic teamfocused leader
# 8    10       seeking human resource human resourcesis generalist position
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 22                  greater boston area       0.032   0.402560      0.879294
# 16           greater new york city area       1.000   0.227186      0.826671
# 26                 united state america       1.000   0.231303      0.810355
# 49  raleighdurham , north carolina area       1.000   0.231303      0.809823
# 30                  austin , texas area       0.348   0.375301      0.895872
# 8             greater philadelphia area       1.000   0.262936      0.880467
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 2              0.950395   0.924892      0.984363  0.933594
# 45             0.950395   0.924892      0.984363  0.933594
# 5              0.912262   0.934877      0.969928  0.964565
# 21             0.875945   0.908395      0.938275  0.922119
# 22             0.874494   0.871642      0.931923  0.958796
# 16             0.741441   0.704786      0.893584  0.940522
# 26             0.780322   0.797933      0.889861  0.976990
# 49             0.780322   0.797933      0.889861  0.980470
# 30             0.827266   0.824088      0.885884  0.888631
# 8              0.760450   0.805695      0.884100  0.845393

# %% [markdown]
# #### f) For BERT

# %%
final_df.sort_values(['Bert_fit'], ascending=False).head(10)
# Out:
#      id                                                     job_title  \
# 51  103                                            always set success
# 49  101                             human resource generalist loparex
# 26   78                             human resource generalist schwans
# 13   28                            seeking human resource opportunity
# 5     6                            aspiring human resource specialist
# 11   13  human resource coordinator intercontinental buckhead atlanta
# 7     8                              human resource senior specialist
# 9    11                                    student chapman university
# 47   99                               seeking human resource position
# 22   74                                   human resource professional
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 51             greater los angeles area       1.000   0.000000      0.340498
# 49  raleighdurham , north carolina area       1.000   0.231303      0.809823
# 26                 united state america       1.000   0.231303      0.810355
# 13                   chicago , illinois       0.780   0.271462      0.884136
# 5            greater new york city area       0.002   0.676406      0.949678
# 11                    atlanta , georgia       1.000   0.153334      0.794771
# 7                san francisco bay area       1.000   0.248041      0.834420
# 9              lake forest , california       0.004   0.000000      0.436173
# 47                la vega , nevada area       0.096   0.280808      0.894779
# 22                  greater boston area       0.032   0.402560      0.879294
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 51             0.213981   0.361773      0.282368  0.981850
# 49             0.780322   0.797933      0.889861  0.980470
# 26             0.780322   0.797933      0.889861  0.976990
# 13             0.756767   0.837561      0.877444  0.975341
# 5              0.912262   0.934877      0.969928  0.964565
# 11             0.578070   0.559741      0.654652  0.962325
# 7              0.697906   0.764780      0.822855  0.961523
# 9              0.244274   0.313866      0.335059  0.960531
# 47             0.728513   0.785119      0.850613  0.959093
# 22             0.874494   0.871642      0.931923  0.958796

# %% [markdown]
# ### 2) For "Seeking human resources"

# %% [markdown]
# #### a) For TFIDF

# %%
final_df_kw2.sort_values(['tfidf_fit'], ascending=False).head(10)
# Out:
#     id                                                          job_title  \
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 12  27      aspiring human resource management student seeking internship
# 20  72          business management major aspiring human resource manager
# 14  66    experienced retail manager aspiring human resource professional
# 22  74                                        human resource professional
# 6    7          student humber college aspiring human resource generalist
# 30  82  aspiring human resource professional energetic teamfocused leader
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 45                kokomo , indiana area       0.142   0.767650      0.859485
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 5            greater new york city area       0.002   0.676406      0.842872
# 21                 houston , texas area       0.014   0.612429      0.946601
# 12                 houston , texas area       1.000   0.429728      0.855958
# 20              monroe , louisiana area       0.010   0.427448      0.858703
# 14                  austin , texas area       0.114   0.406130      0.814708
# 22                  greater boston area       0.032   0.402560      0.869644
# 6                                canada       0.122   0.391946      0.801875
# 30                  austin , texas area       0.348   0.375301      0.823290
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 45             0.422934   0.459776      0.388841  0.888918
# 2              0.127382   0.403659      0.252584  0.867738
# 5              0.723763   0.792764      0.877064  0.924877
# 21             0.268558   0.513656      0.281134  0.827690
# 12             0.237063   0.305832      0.235586  0.832970
# 20             0.759907   0.836470      0.884207  0.955644
# 14             0.632909   0.600964      0.684716  0.888156
# 22             0.706520   0.801243      0.815128  0.951196
# 6              0.870324   0.914206      0.947450  0.842429
# 30             0.164599   0.298825      0.263629  0.954817

# %% [markdown]
# #### b) For Word2Vec

# %%
final_df_kw2.sort_values(['Word2Vec_Fit'], ascending=False).head(10)
# Out:
#      id  \
# 47   99
# 21   73
# 13   28
# 8    10
# 48  100
# 36   88
# 23   75
# 22   74
# 2     3
# 45   97
#
#                                                                                              job_title  \
# 47                                                                     seeking human resource position
# 21                                   aspiring human resource manager seeking internship human resource
# 13                                                                  seeking human resource opportunity
# 8                                         seeking human resource human resourcesis generalist position
# 48  aspiring human resource manager graduating may seeking entrylevel human resource position st louis
# 36                                                                     human resource management major
# 23                          nortia staffing seeking human resource payroll administrative professional
# 22                                                                         human resource professional
# 2                                                                 aspiring human resource professional
# 45                                                                aspiring human resource professional
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 47                la vega , nevada area       0.096   0.280808      0.957151
# 21                 houston , texas area       0.014   0.612429      0.946601
# 13                   chicago , illinois       0.780   0.271462      0.943784
# 8             greater philadelphia area       1.000   0.262936      0.903312
# 48            cape girardeau , missouri       0.206   0.373131      0.888368
# 36                milpitas , california       0.036   0.248041      0.883509
# 23                san jose , california       1.000   0.141157      0.874903
# 22                  greater boston area       0.032   0.402560      0.869644
# 2   raleighdurham , north carolina area       0.088   0.767650      0.859485
# 45                kokomo , indiana area       0.142   0.767650      0.859485
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 47             0.718755   0.803569      0.845641  0.927217
# 21             0.268558   0.513656      0.281134  0.827690
# 13             0.904508   0.956014      0.977981  0.982861
# 8              0.671721   0.748888      0.837362  0.883730
# 48             0.599692   0.695179      0.568251  0.819739
# 36             0.573690   0.672508      0.603170  0.799135
# 23             0.646103   0.767653      0.628124  0.857442
# 22             0.706520   0.801243      0.815128  0.951196
# 2              0.127382   0.403659      0.252584  0.867738
# 45             0.422934   0.459776      0.388841  0.888918

# %% [markdown]
# #### c) For Google Word2Vec

# %%
final_df_kw2.sort_values(['Google_Word2vec_fit'], ascending=False).head(10)
# Out:
#     id  \
# 38  90
# 13  28
# 6    7
# 16  68
# 15  67
# 1    2
# 24  76
# 20  72
# 31  83
# 35  87
#
#                                                                                              job_title  \
# 38                                                     undergraduate research assistant styczynski lab
# 13                                                                  seeking human resource opportunity
# 6                                            student humber college aspiring human resource generalist
# 16                                                                 human resource specialist luxottica
# 15                                                     human resource staffing recruiting professional
# 1                                   native english teacher english program korea english program korea
# 24  aspiring human resource professional passionate helping create inclusive engaging work environment
# 20                                           business management major aspiring human resource manager
# 31                                                  human resource manager endemol shine north america
# 35                                             bachelor science biology victoria university wellington
#
#                       location  connection  tfidf_fit  Word2Vec_Fit  \
# 38        greater atlanta area       0.310   0.000000      0.425043
# 13          chicago , illinois       0.780   0.271462      0.943784
# 6                       canada       0.122   0.391946      0.801875
# 16  greater new york city area       1.000   0.227186      0.808715
# 15  jackson , mississippi area       1.000   0.198735      0.795123
# 1                       canada       1.000   0.000000      0.527206
# 24         new york , new york       0.424   0.257280      0.773791
# 20     monroe , louisiana area       0.010   0.427448      0.858703
# 31    los angeles , california       0.536   0.148305      0.815474
# 35        baltimore , maryland       0.080   0.000000      0.569281
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 38             0.918737   0.938362      0.959728  0.963576
# 13             0.904508   0.956014      0.977981  0.982861
# 6              0.870324   0.914206      0.947450  0.842429
# 16             0.842598   0.908195      0.931645  0.912021
# 15             0.799299   0.855232      0.911936  0.949881
# 1              0.771333   0.812123      0.581721  0.870009
# 24             0.770908   0.740110      0.901139  0.936163
# 20             0.759907   0.836470      0.884207  0.955644
# 31             0.757564   0.794645      0.885821  0.973780
# 35             0.757564   0.794645      0.885821  0.977471

# %% [markdown]
# #### d) For Glove

# %%
final_df_kw2.sort_values(['Glove_fit'], ascending=False).head(10)
# Out:
#      id  \
# 13   28
# 38   90
# 6     7
# 16   68
# 15   67
# 44   96
# 51  103
# 20   72
# 1     2
# 47   99
#
#                                                                                      job_title  \
# 13                                                          seeking human resource opportunity
# 38                                             undergraduate research assistant styczynski lab
# 6                                    student humber college aspiring human resource generalist
# 16                                                         human resource specialist luxottica
# 15                                             human resource staffing recruiting professional
# 44  student indiana university kokomo business management retail manager delphi hardware paint
# 51                                                                          always set success
# 20                                   business management major aspiring human resource manager
# 1                           native english teacher english program korea english program korea
# 47                                                             seeking human resource position
#
#                       location  connection  tfidf_fit  Word2Vec_Fit  \
# 13          chicago , illinois       0.780   0.271462      0.943784
# 38        greater atlanta area       0.310   0.000000      0.425043
# 6                       canada       0.122   0.391946      0.801875
# 16  greater new york city area       1.000   0.227186      0.808715
# 15  jackson , mississippi area       1.000   0.198735      0.795123
# 44         lafayette , indiana       0.038   0.000000      0.676229
# 51    greater los angeles area       1.000   0.000000      0.304366
# 20     monroe , louisiana area       0.010   0.427448      0.858703
# 1                       canada       1.000   0.000000      0.527206
# 47       la vega , nevada area       0.096   0.280808      0.957151
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 13             0.904508   0.956014      0.977981  0.982861
# 38             0.918737   0.938362      0.959728  0.963576
# 6              0.870324   0.914206      0.947450  0.842429
# 16             0.842598   0.908195      0.931645  0.912021
# 15             0.799299   0.855232      0.911936  0.949881
# 44             0.733012   0.853648      0.795586  0.934132
# 51             0.754709   0.843359      0.793411  0.847278
# 20             0.759907   0.836470      0.884207  0.955644
# 1              0.771333   0.812123      0.581721  0.870009
# 47             0.718755   0.803569      0.845641  0.927217

# %% [markdown]
# #### e) For Fasttext

# %%
final_df_kw2.sort_values(['Fasttext_Fit'], ascending=False).head(10)
# Out:
#     id  \
# 13  28
# 38  90
# 6    7
# 16  68
# 15  67
# 24  76
# 35  87
# 31  83
# 20  72
# 40  92
#
#                                                                                              job_title  \
# 13                                                                  seeking human resource opportunity
# 38                                                     undergraduate research assistant styczynski lab
# 6                                            student humber college aspiring human resource generalist
# 16                                                                 human resource specialist luxottica
# 15                                                     human resource staffing recruiting professional
# 24  aspiring human resource professional passionate helping create inclusive engaging work environment
# 35                                             bachelor science biology victoria university wellington
# 31                                                  human resource manager endemol shine north america
# 20                                           business management major aspiring human resource manager
# 40                                 seeking employment opportunity within customer service patient care
#
#                       location  connection  tfidf_fit  Word2Vec_Fit  \
# 13          chicago , illinois       0.780   0.271462      0.943784
# 38        greater atlanta area       0.310   0.000000      0.425043
# 6                       canada       0.122   0.391946      0.801875
# 16  greater new york city area       1.000   0.227186      0.808715
# 15  jackson , mississippi area       1.000   0.198735      0.795123
# 24         new york , new york       0.424   0.257280      0.773791
# 35        baltimore , maryland       0.080   0.000000      0.569281
# 31    los angeles , california       0.536   0.148305      0.815474
# 20     monroe , louisiana area       0.010   0.427448      0.858703
# 40       torrance , california       0.128   0.000000      0.678700
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 13             0.904508   0.956014      0.977981  0.982861
# 38             0.918737   0.938362      0.959728  0.963576
# 6              0.870324   0.914206      0.947450  0.842429
# 16             0.842598   0.908195      0.931645  0.912021
# 15             0.799299   0.855232      0.911936  0.949881
# 24             0.770908   0.740110      0.901139  0.936163
# 35             0.757564   0.794645      0.885821  0.977471
# 31             0.757564   0.794645      0.885821  0.973780
# 20             0.759907   0.836470      0.884207  0.955644
# 40             0.723763   0.792764      0.877064  0.924877

# %% [markdown]
# #### f) For BERT

# %%
final_df_kw2.sort_values(['Bert_fit'], ascending=False).head(10)
# Out:
#     id                                                          job_title  \
# 13  28                                 seeking human resource opportunity
# 33  85      rrp brand portfolio executive jti japan tobacco international
# 35  87            bachelor science biology victoria university wellington
# 31  83                 human resource manager endemol shine north america
# 27  79                  liberal art major aspiring human resource analyst
# 38  90                    undergraduate research assistant styczynski lab
# 20  72          business management major aspiring human resource manager
# 30  82  aspiring human resource professional energetic teamfocused leader
# 22  74                                        human resource professional
# 15  67                    human resource staffing recruiting professional
#
#                         location  connection  tfidf_fit  Word2Vec_Fit  \
# 13            chicago , illinois       0.780   0.271462      0.943784
# 33     greater philadelphia area       1.000   0.000000      0.694551
# 35          baltimore , maryland       0.080   0.000000      0.569281
# 31      los angeles , california       0.536   0.148305      0.815474
# 27  baton rouge , louisiana area       0.014   0.351478      0.828845
# 38          greater atlanta area       0.310   0.000000      0.425043
# 20       monroe , louisiana area       0.010   0.427448      0.858703
# 30           austin , texas area       0.348   0.375301      0.823290
# 22           greater boston area       0.032   0.402560      0.869644
# 15    jackson , mississippi area       1.000   0.198735      0.795123
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit
# 13             0.904508   0.956014      0.977981  0.982861
# 33             0.150533   0.434082      0.266974  0.978145
# 35             0.757564   0.794645      0.885821  0.977471
# 31             0.757564   0.794645      0.885821  0.973780
# 27             0.594030   0.592933      0.635967  0.964595
# 38             0.918737   0.938362      0.959728  0.963576
# 20             0.759907   0.836470      0.884207  0.955644
# 30             0.164599   0.298825      0.263629  0.954817
# 22             0.706520   0.801243      0.815128  0.951196
# 15             0.799299   0.855232      0.911936  0.949881

# %% [markdown]
# ## Goal1 : Predict how fit the candidate is based on their available information (variable fit)

# %% [markdown]
# **Ans:**
# From the above visual inspection of the query results for the two different set of keywords , it was found that **Word2vec** algorithm trained on the above dataset worked better. The reason behind beating the renowned algorithms which have been trained on massive corpus seems to be the fact that the **dataset we have is small** with fewer number of records, due to which an algorithm trained and fitted on our specific dataset provides us with more relevant results. Going ahead with word2vec for calculating fitness score.

# %% [markdown]
# We will consider our <b><i>fitness score</i><b> as **F(x) = 0.9 * Word2Vec_fit + 0.1 * connections**

# %% [markdown]
# So appending the fit column back in our final datasets :

# %%
final_df['fit'] = 0.9 * final_df['Word2Vec_Fit'] + 0.1 * final_df['connection']
final_df = final_df.sort_values(['fit'], ascending=False)
final_df.head()
# Out:
#     id                                                      job_title  \
# 8   10   seeking human resource human resourcesis generalist position
# 13  28                             seeking human resource opportunity
# 12  27  aspiring human resource management student seeking internship
# 45  97                           aspiring human resource professional
# 2    3                           aspiring human resource professional
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 8             greater philadelphia area       1.000   0.262936      0.880467
# 13                   chicago , illinois       0.780   0.271462      0.884136
# 12                 houston , texas area       1.000   0.429728      0.859015
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit       fit
# 8              0.760450   0.805695      0.884100  0.845393  0.892420
# 13             0.756767   0.837561      0.877444  0.975341  0.873723
# 12             0.783973   0.815054      0.866789  0.936784  0.873113
# 45             0.950395   0.924892      0.984363  0.933594  0.870912
# 2              0.950395   0.924892      0.984363  0.933594  0.865512

# %% [markdown]
# So here we see that candidates with ids 10,28,27,97 and 3 are most fit based on both connections and job title. But if we take a closer look we can star 97, 3 as higher than others. And 27 is least fit as he is a student. This will be taken care of in <i> reranking </i>

# %%
final_df_kw2['fit'] = 0.9 * final_df_kw2['Word2Vec_Fit'] + 0.1 * final_df_kw2['connection']
final_df_kw2 = final_df_kw2.sort_values(['fit'], ascending=False)
final_df_kw2.head()
# Out:
#     id  \
# 13  28
# 8   10
# 23  75
# 47  99
# 12  27
#
#                                                                      job_title  \
# 13                                          seeking human resource opportunity
# 8                 seeking human resource human resourcesis generalist position
# 23  nortia staffing seeking human resource payroll administrative professional
# 47                                             seeking human resource position
# 12               aspiring human resource management student seeking internship
#
#                      location  connection  tfidf_fit  Word2Vec_Fit  \
# 13         chicago , illinois       0.780   0.271462      0.943784
# 8   greater philadelphia area       1.000   0.262936      0.903312
# 23      san jose , california       1.000   0.141157      0.874903
# 47      la vega , nevada area       0.096   0.280808      0.957151
# 12       houston , texas area       1.000   0.429728      0.855958
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit       fit
# 13             0.904508   0.956014      0.977981  0.982861  0.927406
# 8              0.671721   0.748888      0.837362  0.883730  0.912980
# 23             0.646103   0.767653      0.628124  0.857442  0.887413
# 47             0.718755   0.803569      0.845641  0.927217  0.871036
# 12             0.237063   0.305832      0.235586  0.832970  0.870362

# %% [markdown]
# For "seeking human resources" keyword search query, we see that candidates with ids 10,28,75, 99 and 27 are most fit based on both connections and job title. And if we again take a closer look we can remove 27 as is least fit because seeking internship and not experienced. This will be taken care of in <i> reranking </i>

# %% [markdown]
# ## Goal2: Re-rank candidates when a candidate is starred.

# %% [markdown]
# Ans: There are a number of **Learning to Rank Algorithms** which can take care of this set of problems. This is a special subset of machine learning problems that does not fall clearly as a regression or a classification alfgorithm and is taken care of in different ways. Some of the ways being:
#
# 1) *Pointwise Methods*:
#     Pointwise methods treat the ranking problem as a regression or classification task. Each item is treated as an independent instance, and the model is trained to predict a relevance score or label for each item. Examples: Linear regression, logistic regression, support vector machines (SVM), and decision trees can be adapted for pointwise ranking.
#
# 2) *Pairwise Methods*:
#     Pairwise methods consider pairs of items and learn to rank them relative to each other. The model is trained to differentiate between pairs of items, indicating which item in each pair is more relevant. Examples: RankNet, RankBoost, and RankBoost variants, such as AdaRank, are pairwise LTR algorithms.
#
# 3) *Listwise Methods*:
#     Listwise methods take into account the entire ranked list of items for a query. These methods optimize a ranking measure directly, aiming to maximize the quality of the entire ranked list. Examples: ListNet, ListMLE (Listwise Maximum Likelihood Estimation), and LambdaMART are examples of listwise LTR algorithms.
#
# We will be going ahead with the Listwise Method which seems to appropriately fit our criterion as we have a list of job titles from the dataframe which needs to be ranked. And it should not be computationally as intensive as the size of the dataset is not large. So will be proceeding with **LambdaMART with LightGBM** algorithm first.

# %% [markdown]
# First we will add a column titled <u><i>starred</u></i> in our final dataframe to keep track of whether a candidate is starred or not. Herein 1 means starred and 0 means not starred.

# %%
final_df['starred'] = 0

# Starring candidates 10,28,97,3
final_df.loc[final_df['id'] == 10, 'starred'] = 1
final_df.loc[final_df['id'] == 28, 'starred'] = 1
final_df.loc[final_df['id'] == 97, 'starred'] = 1
final_df.loc[final_df['id'] == 3, 'starred'] = 1

final_df = final_df.sort_values(['fit'], ascending=False)
final_df.head(10)
# Out:
#     id                                                          job_title  \
# 8   10       seeking human resource human resourcesis generalist position
# 13  28                                 seeking human resource opportunity
# 12  27      aspiring human resource management student seeking internship
# 45  97                               aspiring human resource professional
# 2    3                               aspiring human resource professional
# 5    6                                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking internship human resource
# 7    8                                   human resource senior specialist
# 19  71                          human resource generalist scottmadden inc
# 29  81          senior human resource business partner heil environmental
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 8             greater philadelphia area       1.000   0.262936      0.880467
# 13                   chicago , illinois       0.780   0.271462      0.884136
# 12                 houston , texas area       1.000   0.429728      0.859015
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 7                san francisco bay area       1.000   0.248041      0.834420
# 19  raleighdurham , north carolina area       1.000   0.185021      0.833427
# 29         chattanooga , tennessee area       0.910   0.145662      0.837309
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit       fit  starred
# 8              0.760450   0.805695      0.884100  0.845393  0.892420        1
# 13             0.756767   0.837561      0.877444  0.975341  0.873723        1
# 12             0.783973   0.815054      0.866789  0.936784  0.873113        0
# 45             0.950395   0.924892      0.984363  0.933594  0.870912        1
# 2              0.950395   0.924892      0.984363  0.933594  0.865512        1
# 5              0.912262   0.934877      0.969928  0.964565  0.854910        0
# 21             0.875945   0.908395      0.938275  0.922119  0.852087        0
# 7              0.697906   0.764780      0.822855  0.961523  0.850978        0
# 19             0.672638   0.737717      0.566922  0.927363  0.850084        0
# 29             0.648945   0.718803      0.640661  0.867658  0.844578        0

# %% [markdown]
# ### Implementing Ranking algorithm LambdaMART with lightgbm

# %%
import lightgbm as lgb

# %%
# A ranking algorithm which takes as input the df, feature columns, target and returns the ranked df according to columns
def ranking(dataframe, features, target):
    # Create an augmented dataset with manually selected candidates
    augmented_df = dataframe.copy()

    # Feature engineering 
    X = augmented_df[features]
    y = augmented_df[target]

    # Train a LambdaMART model on the augmented dataset
    lgb_dataset = lgb.Dataset(X, label=y, group=[len(augmented_df)])  # Group all instances together
    params = {"objective": "lambdarank", "metric": "ndcg"}  # LambdaMART parameters
    model = lgb.train(params, lgb_dataset, num_boost_round=100)

    # Make predictions for all candidates 
    augmented_df["Predicted_Score"] = model.predict(X)

    # Sort candidates based on predicted scores
    sorted_candidates = augmented_df.sort_values(by="Predicted_Score", ascending=False)
    return sorted_candidates

# %%
# A ranking algorithm which takes as input the df, feature columns, output and returns the ranked df according to columns
# def ranking(dataframe, features, y):
#     # Create an augmented dataset with manually selected candidates
#     augmented_df = datframe.copy()

#     # Feature engineering 
#     X = augmented_df[["connection", "Word2Vec_Fit", "fit"]]
#     y = augmented_df["starred"]

#     # Train a LambdaMART model on the augmented dataset
#     lgb_dataset = lgb.Dataset(X, label=y, group=[len(augmented_df)])  # Group all instances together
#     params = {"objective": "lambdarank", "metric": "ndcg"}  # LambdaMART parameters
#     model = lgb.train(params, lgb_dataset, num_boost_round=100)

#     # Make predictions for all candidates 
#     augmented_df["Predicted_Score"] = model.predict(X)

#     # Sort candidates based on predicted scores
#     sorted_candidates = augmented_df.sort_values(by="Predicted_Score", ascending=False)
#     return sorted_candidates
sorted_candidates = ranking(final_df, ["connection", "Word2Vec_Fit", "fit"], "starred")

# Print the re-ranked list of candidates
sorted_candidates[['id', 'job_title','location', 'Word2Vec_Fit','fit','starred','Predicted_Score']].head(20)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000785 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 51
# [LightGBM] [Info] Number of data points in the train set: 53, number of used features: 3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#      id  \
# 13   28
# 45   97
# 2     3
# 8    10
# 12   27
# 27   79
# 6     7
# 21   73
# 20   72
# 5     6
# 47   99
# 30   82
# 48  100
# 22   74
# 14   66
# 51  103
# 52  104
# 3     4
# 1     2
# 4     5
#
#                                                                                              job_title  \
# 13                                                                  seeking human resource opportunity
# 45                                                                aspiring human resource professional
# 2                                                                 aspiring human resource professional
# 8                                         seeking human resource human resourcesis generalist position
# 12                                       aspiring human resource management student seeking internship
# 27                                                   liberal art major aspiring human resource analyst
# 6                                            student humber college aspiring human resource generalist
# 21                                   aspiring human resource manager seeking internship human resource
# 20                                           business management major aspiring human resource manager
# 5                                                                   aspiring human resource specialist
# 47                                                                     seeking human resource position
# 30                                   aspiring human resource professional energetic teamfocused leader
# 48  aspiring human resource manager graduating may seeking entrylevel human resource position st louis
# 22                                                                         human resource professional
# 14                                     experienced retail manager aspiring human resource professional
# 51                                                                                  always set success
# 52                                                          director administration excellence logging
# 3                                                                  people development coordinator ryan
# 1                                   native english teacher english program korea english program korea
# 4                                                         advisory board member celal bayar university
#
#                                location  Word2Vec_Fit       fit  starred  \
# 13                   chicago , illinois      0.884136  0.873723        1
# 45                kokomo , indiana area      0.951902  0.870912        1
# 2   raleighdurham , north carolina area      0.951902  0.865512        1
# 8             greater philadelphia area      0.880467  0.892420        1
# 12                 houston , texas area      0.859015  0.873113        0
# 27         baton rouge , louisiana area      0.890232  0.802609        0
# 6                                canada      0.890077  0.813269        0
# 21                 houston , texas area      0.945208  0.852087        0
# 20              monroe , louisiana area      0.915736  0.825162        0
# 5            greater new york city area      0.949678  0.854910        0
# 47                la vega , nevada area      0.894779  0.814901        0
# 30                  austin , texas area      0.895872  0.841085        0
# 48            cape girardeau , missouri      0.911749  0.841174        0
# 22                  greater boston area      0.879294  0.794564        0
# 14                  austin , texas area      0.873018  0.797116        0
# 51             greater los angeles area      0.340498  0.406448        0
# 52                         katy , texas      0.363613  0.427251        0
# 3                        denton , texas      0.512342  0.561107        0
# 1                                canada      0.567805  0.611025        0
# 4                       i̇zmir , turkey      0.612540  0.651286        0
#
#     Predicted_Score
# 13         3.800410
# 45         2.601690
# 2          2.601690
# 8          1.475732
# 12         0.162425
# 27        -1.521993
# 6         -1.521993
# 21        -1.525083
# 20        -1.525083
# 5         -1.525083
# 47        -1.525083
# 30        -1.623865
# 48        -1.623865
# 22        -3.839379
# 14        -3.841875
# 51        -3.892020
# 52        -3.892020
# 3         -3.892020
# 1         -3.892020
# 4         -3.892020

# %% [markdown]
# #### Let us star more candidates and see what happens to the ranking.

# %%
# Starring more candidates 79,73,72,6,99,82,66
final_df.loc[final_df['id'] == 79, 'starred'] = 1
final_df.loc[final_df['id'] == 73, 'starred'] = 1
final_df.loc[final_df['id'] == 72, 'starred'] = 1
final_df.loc[final_df['id'] == 6, 'starred'] = 1
final_df.loc[final_df['id'] == 99, 'starred'] = 1
final_df.loc[final_df['id'] == 82, 'starred'] = 1
final_df.loc[final_df['id'] == 66, 'starred'] = 1

final_df = final_df.sort_values(['fit'], ascending=False)
final_df.head(20)
# Out:
#      id  \
# 8    10
# 13   28
# 12   27
# 45   97
# 2     3
# 5     6
# 21   73
# 7     8
# 19   71
# 29   81
# 16   68
# 48  100
# 30   82
# 23   75
# 37   89
# 26   78
# 49  101
# 20   72
# 10   12
# 11   13
#
#                                                                                                                                                                   job_title  \
# 8                                                                                                              seeking human resource human resourcesis generalist position
# 13                                                                                                                                       seeking human resource opportunity
# 12                                                                                                            aspiring human resource management student seeking internship
# 45                                                                                                                                     aspiring human resource professional
# 2                                                                                                                                      aspiring human resource professional
# 5                                                                                                                                        aspiring human resource specialist
# 21                                                                                                        aspiring human resource manager seeking internship human resource
# 7                                                                                                                                          human resource senior specialist
# 19                                                                                                                                human resource generalist scottmadden inc
# 29                                                                                                                senior human resource business partner heil environmental
# 16                                                                                                                                      human resource specialist luxottica
# 48                                                                       aspiring human resource manager graduating may seeking entrylevel human resource position st louis
# 30                                                                                                        aspiring human resource professional energetic teamfocused leader
# 23                                                                                               nortia staffing seeking human resource payroll administrative professional
# 37                                                                                                                       director human resource ernst young global limited
# 26                                                                                                                                        human resource generalist schwans
# 49                                                                                                                                        human resource generalist loparex
# 20                                                                                                                business management major aspiring human resource manager
# 10  senior vice president chuman resourceso marketing communication corporate social responsibility officer engie houston woodland energy gphuman resource sphuman resource
# 11                                                                                                             human resource coordinator intercontinental buckhead atlanta
#
#                                location  connection  tfidf_fit  Word2Vec_Fit  \
# 8             greater philadelphia area       1.000   0.262936      0.880467
# 13                   chicago , illinois       0.780   0.271462      0.884136
# 12                 houston , texas area       1.000   0.429728      0.859015
# 45                kokomo , indiana area       0.142   0.767650      0.951902
# 2   raleighdurham , north carolina area       0.088   0.767650      0.951902
# 5            greater new york city area       0.002   0.676406      0.949678
# 21                 houston , texas area       0.014   0.612429      0.945208
# 7                san francisco bay area       1.000   0.248041      0.834420
# 19  raleighdurham , north carolina area       1.000   0.185021      0.833427
# 29         chattanooga , tennessee area       0.910   0.145662      0.837309
# 16           greater new york city area       1.000   0.227186      0.826671
# 48            cape girardeau , missouri       0.206   0.373131      0.911749
# 30                  austin , texas area       0.348   0.375301      0.895872
# 23                san jose , california       1.000   0.141157      0.814703
# 37                 greater atlanta area       0.698   0.138910      0.845446
# 26                 united state america       1.000   0.231303      0.810355
# 49  raleighdurham , north carolina area       1.000   0.231303      0.809823
# 20              monroe , louisiana area       0.010   0.427448      0.915736
# 10                 houston , texas area       1.000   0.074450      0.802190
# 11                    atlanta , georgia       1.000   0.153334      0.794771
#
#     Google_Word2vec_fit  Glove_fit  Fasttext_Fit  Bert_fit       fit  starred
# 8              0.760450   0.805695      0.884100  0.845393  0.892420        1
# 13             0.756767   0.837561      0.877444  0.975341  0.873723        1
# 12             0.783973   0.815054      0.866789  0.936784  0.873113        0
# 45             0.950395   0.924892      0.984363  0.933594  0.870912        1
# 2              0.950395   0.924892      0.984363  0.933594  0.865512        1
# 5              0.912262   0.934877      0.969928  0.964565  0.854910        1
# 21             0.875945   0.908395      0.938275  0.922119  0.852087        1
# 7              0.697906   0.764780      0.822855  0.961523  0.850978        0
# 19             0.672638   0.737717      0.566922  0.927363  0.850084        0
# 29             0.648945   0.718803      0.640661  0.867658  0.844578        0
# 16             0.741441   0.704786      0.893584  0.940522  0.844004        0
# 48             0.791290   0.774596      0.584913  0.882259  0.841174        0
# 30             0.827266   0.824088      0.885884  0.888631  0.841085        1
# 23             0.616633   0.677011      0.747578  0.955413  0.833233        0
# 37             0.714341   0.727025      0.715189  0.890428  0.830701        0
# 26             0.780322   0.797933      0.889861  0.976990  0.829319        0
# 49             0.780322   0.797933      0.889861  0.980470  0.828840        0
# 20             0.760062   0.756317      0.812208  0.931662  0.825162        1
# 10             0.576280   0.604260      0.573702  0.828574  0.821971        0
# 11             0.578070   0.559741      0.654652  0.962325  0.815294        0

# %%
sorted_candidates = ranking(final_df, ["connection", "Word2Vec_Fit", "fit"], "starred")

# Print the re-ranked list of candidates
sorted_candidates[['id', 'job_title','location', 'Word2Vec_Fit','fit','starred','Predicted_Score']].head(20)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000075 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51
# [LightGBM] [Info] Number of data points in the train set: 53, number of used features: 3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#      id  \
# 2     3
# 5     6
# 21   73
# 20   72
# 45   97
# 47   99
# 13   28
# 27   79
# 8    10
# 30   82
# 48  100
# 14   66
# 22   74
# 6     7
# 12   27
# 7     8
# 36   88
# 29   81
# 19   71
# 16   68
#
#                                                                                              job_title  \
# 2                                                                 aspiring human resource professional
# 5                                                                   aspiring human resource specialist
# 21                                   aspiring human resource manager seeking internship human resource
# 20                                           business management major aspiring human resource manager
# 45                                                                aspiring human resource professional
# 47                                                                     seeking human resource position
# 13                                                                  seeking human resource opportunity
# 27                                                   liberal art major aspiring human resource analyst
# 8                                         seeking human resource human resourcesis generalist position
# 30                                   aspiring human resource professional energetic teamfocused leader
# 48  aspiring human resource manager graduating may seeking entrylevel human resource position st louis
# 14                                     experienced retail manager aspiring human resource professional
# 22                                                                         human resource professional
# 6                                            student humber college aspiring human resource generalist
# 12                                       aspiring human resource management student seeking internship
# 7                                                                     human resource senior specialist
# 36                                                                     human resource management major
# 29                                           senior human resource business partner heil environmental
# 19                                                           human resource generalist scottmadden inc
# 16                                                                 human resource specialist luxottica
#
#                                location  Word2Vec_Fit       fit  starred  \
# 2   raleighdurham , north carolina area      0.951902  0.865512        1
# 5            greater new york city area      0.949678  0.854910        1
# 21                 houston , texas area      0.945208  0.852087        1
# 20              monroe , louisiana area      0.915736  0.825162        1
# 45                kokomo , indiana area      0.951902  0.870912        1
# 47                la vega , nevada area      0.894779  0.814901        1
# 13                   chicago , illinois      0.884136  0.873723        1
# 27         baton rouge , louisiana area      0.890232  0.802609        1
# 8             greater philadelphia area      0.880467  0.892420        1
# 30                  austin , texas area      0.895872  0.841085        1
# 48            cape girardeau , missouri      0.911749  0.841174        0
# 14                  austin , texas area      0.873018  0.797116        1
# 22                  greater boston area      0.879294  0.794564        0
# 6                                canada      0.890077  0.813269        0
# 12                 houston , texas area      0.859015  0.873113        0
# 7                san francisco bay area      0.834420  0.850978        0
# 36                milpitas , california      0.861095  0.778585        0
# 29         chattanooga , tennessee area      0.837309  0.844578        0
# 19  raleighdurham , north carolina area      0.833427  0.850084        0
# 16           greater new york city area      0.826671  0.844004        0
#
#     Predicted_Score
# 2          3.881954
# 5          3.881954
# 21         3.881954
# 20         2.432950
# 45         2.008225
# 47         1.685873
# 13         1.374621
# 27         1.151765
# 8          0.597765
# 30         0.579789
# 48         0.488352
# 14         0.170214
# 22        -0.081838
# 6         -0.888423
# 12        -1.347500
# 7         -1.675807
# 36        -2.027103
# 29        -2.034792
# 19        -2.281719
# 16        -2.281719

# %% [markdown]
# ## Bonus(es):

# %% [markdown]
# ### Ques.1. We are interested in a robust algorithm, tell us how your solution works and show us how your ranking gets better with each starring action.

# %% [markdown]
# **Ans**. The solution is pretty robust because after a lot of comparisons (TF-IDF, Word2Vec, Google Word2Vec, Glove, Fasttext and BERT), I was able to find an **NLP embedding algorithm which is particularly well suited to our specific use case data** , ie. the Word2Vec algorithm trained on the words in this dataset. The candidates in the dataset were ranked based on a **fitness score which was based on the cosine similarity metric and normalized connections.** The solution also handles manual starring of candidates with reranking based on **Learning To Rank algorithm (LambaMart with LightGBM)** in which our final predicted_score is better for the candidates that were starred.
#
# Future enhancements: To implement this on large scale, Fasttext or BERT can be used in the above solution.
#
# Plus, the solution above becomes **better with each starring**. This is because as and when the **starred candidate sample size increases**, it helps our LTR algorithm to learn the patterns in the data better. And hence the better results (which can be seen when number of starred candidates was increased to 10).

# %% [markdown]
# ### Ques.2. How can we filter out candidates which in the first place should not be in this list?

# %% [markdown]
# **Ans**. The candidates which should not be in the list can be **filtered out by setting a threshold** for our fitness score. We can take a safe limit of fitness score threshold as 0.40 as not related or candidates who should not be in the list. This is because we can see our min is 0.207 and max is 0.892. And we can cross check with the dataset to confirm.

# %%
final_df.sort_values(['fit'], ascending=False).describe()
# Out:
#                id  connection  tfidf_fit  Word2Vec_Fit  Google_Word2vec_fit  \
# count   53.000000   53.000000  53.000000     53.000000            53.000000
# mean    65.132075    0.483811   0.194236      0.743555             0.566251
# std     35.117954    0.434130   0.204105      0.175023             0.239992
# min      1.000000    0.002000   0.000000      0.229144             0.206563
# 25%     28.000000    0.088000   0.000000      0.622602             0.307312
# 50%     78.000000    0.310000   0.148305      0.811338             0.623142
# 75%     91.000000    1.000000   0.271462      0.873018             0.760062
# max    104.000000    1.000000   0.767650      0.951902             0.950395
#
#        Glove_fit  Fasttext_Fit   Bert_fit        fit    starred
# count  53.000000     53.000000  53.000000  53.000000  53.000000
# mean    0.624114      0.630714   0.903649   0.717580   0.207547
# std     0.200834      0.237342   0.048524   0.162684   0.409432
# min     0.202625      0.186951   0.807109   0.207030   0.000000
# 25%     0.427824      0.379228   0.863759   0.593160   0.000000
# 50%     0.700032      0.654652   0.899871   0.794810   0.000000
# 75%     0.774596      0.833309   0.946331   0.833233   0.000000
# max     0.934877      0.984363   0.981850   0.892420   1.000000

# %% [markdown]
# #### Ques.3. Can we determine a cut-off point that would work for other roles without losing high potential candidates?

# %% [markdown]
# ### Ques.4. Do you have any ideas that we should explore so that we can even automate this procedure to prevent human bias?

# %% [markdown]
# Ans. Human bias can be prevented by updating the dataset with keeping a track of list of candidates which actually get selected for specific queries and updating the score to give higher precedence to selected candidates. The ranking algorithm can be reranked and **starred candidates can be substituted to selected candidates**. This pattern can be learnt and applied to later searches after a generous amount of queries and selected candidates are recorded. Then this procedure will be automated and starring will not be needed, hence no human intervention.
#
# Further enhancements can also be to improve our feature set by including years of experience, educational qualifications, query related skill set, awards or certificates attained and many more.
